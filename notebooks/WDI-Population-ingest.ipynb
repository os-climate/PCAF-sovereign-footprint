# %% [markdown]
# <font size="5">Ingest WDI - "Population" data into Trino pipeline</font>

# %%
from pcaf_env import *
import shutil
import openpyxl
import ParseXLS as parser

pcaf_table_prefix = ''
ingest_table = 'sf_wdi_population'
models_table = 'pcaf_dbt_models'
# Out:
# using connect string: trino://MichaelTiemannOSC@trino-secure-odh-trino.apps.odh-cl2.apps.os-climate.org:443/osc_datacommons_dev
# create schema if not exists osc_datacommons_dev.mdt_sandbox

# %% [markdown]
# Load Environment Variables

# %%
# Show available schemas to ensure trino connection is set correctly
schema_read = engine.execute(f'show schemas in {ingest_catalog}')
for row in schema_read.fetchall():
    print(row)
# Out:
# ('aicoe_osc_demo_results',)
# ('default',)
# ('demo_dv',)
# ('dera',)
# ('essd',)
# ('iceberg_demo',)
# ('information_schema',)
# ('ingest',)
# ('mdt_sandbox',)
# ('pcaf_sovereign_footprint',)
# ('rmi',)
# ('sandbox',)
# ('wri_gppd',)

# %% [markdown]
# Load GDP file (updated sporadically from https://data.worldbank.org/indicator/NY.GDP.PCAP.PP.CD)

# %%
## GDP
pop_data_file = s3_source.Object(os.environ['S3_LANDING_BUCKET'],'PCAF-sovereign-footprint/WDI/Population_Data.csv')
pop_data_file.download_file(f'/tmp/Population_Data.csv')

df = parser.process('WDI_population.ini','WDI_population.csv') 

# year values are delivered twice . remove the unnecessary part

df[['validity_date', 'column_to_drop']] = df['validity_date'].str.split(' ', expand=True)

df.drop('column_to_drop', axis=1, inplace=True)


## GDP PPP

#df=df.astype({'validity_date': 'int32'})
df= df.convert_dtypes()
df.info(verbose=True)
df= df[['rec_source','data_provider','country_iso_code','country_name','validity_date','attribute','value','value_units']].dropna(subset=['value'])
#df = df.convert_dtypes()
df.info(verbose=True)

#df
# Out:
# WDI_population.ini
# file_list:
# ['/tmp/Population_Data.csv']
# /tmp/Population_Data.csv
# 2
# csv
# /tmp/Population_Dat
# <configparser.ConfigParser object at 0x7fd5b7765ac0>
#            Series Name  Series Code
# 0    Population, total  SP.POP.TOTL  \
# 1    Population, total  SP.POP.TOTL
# 2    Population, total  SP.POP.TOTL
# 3    Population, total  SP.POP.TOTL
# 4    Population, total  SP.POP.TOTL
# ..                 ...          ...
# 261  Population, total  SP.POP.TOTL
# 262  Population, total  SP.POP.TOTL
# 263  Population, total  SP.POP.TOTL
# 264  Population, total  SP.POP.TOTL
# 265  Population, total  SP.POP.TOTL
#
#                                    Country Name Country Code 1990 [YR1990]
# 0                                   Afghanistan          AFG      12412311  \
# 1                                       Albania          ALB       3286542
# 2                                       Algeria          DZA      25758872
# 3                                American Samoa          ASM         47351
# 4                                       Andorra          AND         54508
# ..                                          ...          ...           ...
# 261                          Sub-Saharan Africa          SSF     509451875
# 262  Sub-Saharan Africa (excluding high income)          SSA     509382368
# 263   Sub-Saharan Africa (IDA & IBRD countries)          TSS     509451875
# 264                         Upper middle income          UMC    1926685059
# 265                                       World          WLD    5280062644
#
#     2000 [YR2000] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015]
# 0        20779957      31161378      32269592      33370804      34413603  \
# 1         3089027       2900401       2895092       2889104       2880703
# 2        31042238      37383899      38140135      38923688      39728020
# 3           57816         55669         55717         55791         55806
# 4           65390         82427         80770         79213         77993
# ..            ...           ...           ...           ...           ...
# 261     665327588     917725880     943039474     968958352     995458498
# 262     665246457     917637577     942949525     968866993     995365079
# 263     665327588     917725880     943039474     968958352     995458498
# 264    2154077670    2354967527    2374694434    2394063066    2412687400
# 265    6114324044    7089254548    7175500378    7261846543    7347679005
#
#     2016 [YR2016] 2017 [YR2017] 2018 [YR2018] 2019 [YR2019] 2020 [YR2020]
# 0        35383028      36296111      37171922      38041757      38928341  \
# 1         2876101       2873457       2866376       2854191       2837849
# 2        40551398      41389174      42228415      43053054      43851043
# 3           55739         55617         55461         55312         55197
# 4           77295         76997         77008         77146         77265
# ..            ...           ...           ...           ...           ...
# 261    1022530245    1050162810    1078319512    1106957870    1136046775
# 262    1022435568    1050066967    1078222750    1106860245    1135948313
# 263    1022530245    1050162810    1078319512    1106957870    1136046775
# 264    2431145930    2449903406    2466337061    2480707519    2492597173
# 265    7433650819    7519371102    7602716232    7683806444    7763932702
#
#     2021 [YR2021]
# 0        39835428
# 1         2811666
# 2        44616626
# 3           55103
# 4           77354
# ..            ...
# 261    1165563987
# 262    1165464785
# 263    1165563987
# 264    2501427939
# 265    7836630792
#
# [266 rows x 16 columns]
# ['']
# eval_components
# ['Series Name']
# ['Series Name', 'Series Code', 'Country Name', 'Country Code', '1990 [YR1990]', '2000 [YR2000]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]']
# Series Name
# Index(['column names original:Series Name',
#        'column names original:Series Code',
#        'column names original:Country Name',
#        'column names original:Country Code',
#        'column names original:1990 [YR1990]',
#        'column names original:2000 [YR2000]',
#        'column names original:2012 [YR2012]',
#        'column names original:2013 [YR2013]',
#        'column names original:2014 [YR2014]',
#        'column names original:2015 [YR2015]',
#        'column names original:2016 [YR2016]',
#        'column names original:2017 [YR2017]',
#        'column names original:2018 [YR2018]',
#        'column names original:2019 [YR2019]',
#        'column names original:2020 [YR2020]',
#        'column names original:2021 [YR2021]',
#        'column names original:attribute', 'column names original:units'],
#       dtype='object')
# Index(['column names after rename:Series Name',
#        'column names after rename:Series Code',
#        'column names after rename:country_name',
#        'column names after rename:country_iso_code',
#        'column names after rename:1990 [YR1990]',
#        'column names after rename:2000 [YR2000]',
#        'column names after rename:2012 [YR2012]',
#        'column names after rename:2013 [YR2013]',
#        'column names after rename:2014 [YR2014]',
#        'column names after rename:2015 [YR2015]',
#        'column names after rename:2016 [YR2016]',
#        'column names after rename:2017 [YR2017]',
#        'column names after rename:2018 [YR2018]',
#        'column names after rename:2019 [YR2019]',
#        'column names after rename:2020 [YR2020]',
#        'column names after rename:2021 [YR2021]',
#        'column names after rename:attribute',
#        'column names after rename:units'],
#       dtype='object')
# 266
# 266
# before melt
#                                    country_name country_iso_code
# 0                                   Afghanistan              AFG  \
# 1                                       Albania              ALB
# 2                                       Algeria              DZA
# 3                                American Samoa              ASM
# 4                                       Andorra              AND
# ..                                          ...              ...
# 261                          Sub-Saharan Africa              SSF
# 262  Sub-Saharan Africa (excluding high income)              SSA
# 263   Sub-Saharan Africa (IDA & IBRD countries)              TSS
# 264                         Upper middle income              UMC
# 265                                       World              WLD
#
#     1990 [YR1990] 2000 [YR2000] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014]
# 0        12412311      20779957      31161378      32269592      33370804  \
# 1         3286542       3089027       2900401       2895092       2889104
# 2        25758872      31042238      37383899      38140135      38923688
# 3           47351         57816         55669         55717         55791
# 4           54508         65390         82427         80770         79213
# ..            ...           ...           ...           ...           ...
# 261     509451875     665327588     917725880     943039474     968958352
# 262     509382368     665246457     917637577     942949525     968866993
# 263     509451875     665327588     917725880     943039474     968958352
# 264    1926685059    2154077670    2354967527    2374694434    2394063066
# 265    5280062644    6114324044    7089254548    7175500378    7261846543
#
#     2015 [YR2015] 2016 [YR2016] 2017 [YR2017] 2018 [YR2018] 2019 [YR2019]
# 0        34413603      35383028      36296111      37171922      38041757  \
# 1         2880703       2876101       2873457       2866376       2854191
# 2        39728020      40551398      41389174      42228415      43053054
# 3           55806         55739         55617         55461         55312
# 4           77993         77295         76997         77008         77146
# ..            ...           ...           ...           ...           ...
# 261     995458498    1022530245    1050162810    1078319512    1106957870
# 262     995365079    1022435568    1050066967    1078222750    1106860245
# 263     995458498    1022530245    1050162810    1078319512    1106957870
# 264    2412687400    2431145930    2449903406    2466337061    2480707519
# 265    7347679005    7433650819    7519371102    7602716232    7683806444
#
#     2020 [YR2020] 2021 [YR2021]          attribute units
# 0        38928341      39835428  Population, total
# 1         2837849       2811666  Population, total
# 2        43851043      44616626  Population, total
# 3           55197         55103  Population, total
# 4           77265         77354  Population, total
# ..            ...           ...                ...   ...
# 261    1136046775    1165563987  Population, total
# 262    1135948313    1165464785  Population, total
# 263    1136046775    1165563987  Population, total
# 264    2492597173    2501427939  Population, total
# 265    7763932702    7836630792  Population, total
#
# [266 rows x 16 columns]
# after melt
#      country_iso_code                                country_name
# 0                 AFG                                 Afghanistan  \
# 1                 ALB                                     Albania
# 2                 DZA                                     Algeria
# 3                 ASM                              American Samoa
# 4                 AND                                     Andorra
# ...               ...                                         ...
# 3187              SSF                          Sub-Saharan Africa
# 3188              SSA  Sub-Saharan Africa (excluding high income)
# 3189              TSS   Sub-Saharan Africa (IDA & IBRD countries)
# 3190              UMC                         Upper middle income
# 3191              WLD                                       World
#
#               attribute units           year       value
# 0     Population, total        1990 [YR1990]    12412311
# 1     Population, total        1990 [YR1990]     3286542
# 2     Population, total        1990 [YR1990]    25758872
# 3     Population, total        1990 [YR1990]       47351
# 4     Population, total        1990 [YR1990]       54508
# ...                 ...   ...            ...         ...
# 3187  Population, total        2021 [YR2021]  1165563987
# 3188  Population, total        2021 [YR2021]  1165464785
# 3189  Population, total        2021 [YR2021]  1165563987
# 3190  Population, total        2021 [YR2021]  2501427939
# 3191  Population, total        2021 [YR2021]  7836630792
#
# [3192 rows x 6 columns]
# list columns
# ['country_iso_code', 'country_name', 'attribute', 'units', 'year', 'value']
# ['country_iso_code', 'country_name', 'attribute', 'value_units', 'value', 'rec_source', 'data_provider', 'validity_date']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3192 entries, 0 to 3191
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rec_source        3192 non-null   string
#  1   data_provider     3192 non-null   string
#  2   country_name      3192 non-null   string
#  3   country_iso_code  3192 non-null   string
#  4   validity_date     3192 non-null   string
#  5   attribute         3192 non-null   string
#  6   value             3192 non-null   string
#  7   value_units       3192 non-null   string
# dtypes: string(8)
# memory usage: 199.6 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3192 entries, 0 to 3191
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rec_source        3192 non-null   string
#  1   data_provider     3192 non-null   string
#  2   country_iso_code  3192 non-null   string
#  3   country_name      3192 non-null   string
#  4   validity_date     3192 non-null   string
#  5   attribute         3192 non-null   string
#  6   value             3192 non-null   string
#  7   value_units       3192 non-null   string
# dtypes: string(8)
# memory usage: 199.6 KB

# %%
#%run -i TransposeXLS.py --config WDI.ini --output=WDI.csv

# %%
try:
    os.mkdir("/opt/app-root/src/PCAF-sovereign-footprint/dbt/pcaf_transform/models", mode=0o755)
except FileExistsError:
    pass
shutil.rmtree("/opt/app-root/src/PCAF-sovereign-footprint/dbt/pcaf_transform/models/.ipynb_checkpoints", ignore_errors=True)

# %%
custom_meta_content = {
    'data provider': df[['data_provider']],
    'title': 'World Bank GDP per capita, Population',
    'author': 'International Comparison Program, World Bank | World Development Indicators database, World Bank | Eurostat-OECD PPP Programme.',
    'contact': 'data@worldbank.org',
    'description': json.dumps("""
Total population is a mid-year population based on the de facto definition of population, which counts all residents regardless of legal status or citizenship."""),
    'release_date': '2022-01-01 00:00:00',
    # How should we describe our transformative step here?
}

def description_is (s):
    return { 'Description': json.dumps(s)}

custom_meta_fields = {}
custom_meta_fields['rec_source'] = description_is("Population_Data.csv")
custom_meta_fields['data_provider'] = description_is("WDI")
custom_meta_fields['country_iso_code'] = description_is("ISO-3166 Country Code (alpha_3)")
custom_meta_fields['country_name'] = description_is("ISO-3166 Country Name")
custom_meta_fields['attribute'] = description_is("Population, total")
custom_meta_fields['value'] = description_is("Population")
custom_meta_fields['value_units'] = description_is("People, whether citizens or not")
custom_meta_fields['validity_date'] = description_is("Year of measurement")

for f in custom_meta_fields:
    if 'ISO' in custom_meta_fields[f]['Description']:
        custom_meta_fields[f]['tags'] = ['ISO']
    elif 'IPCC' in custom_meta_fields[f]['Description']:
        custom_meta_fields[f]['tags'] = ['IPCC']
    elif 'WDI' in custom_meta_fields[f]['Description']:
        custom_meta_fields[f]['tags'] = ['WDI']
    elif f == 'year':
        custom_meta_fields[f]['tags'] = ['annual']
# Out:
# rec_source
# data_provider
# country_iso_code
# country_name
# attribute
# value
# value_units
# validity_date

# %%
create_trino_table_and_dbt_metadata(ingest_table, df, ['validity_date'], custom_meta_content, custom_meta_fields, verbose=True)
# Out:
# drop table if exists mdt_sandbox.sf_wdi_population_source
# enforcing dataframe partition column order
#
# verifying existence of table osc_datacommons_dev.mdt_sandbox.sf_wdi_population_source
# create table if not exists osc_datacommons_dev.mdt_sandbox.sf_wdi_population_source (
#     rec_source varchar,
#     data_provider varchar,
#     country_iso_code varchar,
#     country_name varchar,
#     attribute varchar,
#     value varchar,
#     value_units varchar,
#     validity_date varchar
# ) with (
#     format = 'parquet',
#     partitioning = array['validity_date']
# )
#
# staging dataframe parquet to s3 osc-datacommons-s3-bucket-dev02
# /tmp/ingest_temp_e560117a/validity_date=1990/bafc673a9a23494e8539a9196bc99265-0.parquet  -->  trino/ingest/ingest_temp_e560117a/validity_date=1990/bafc673a9a23494e8539a9196bc99265-0.parquet
# /tmp/ingest_temp_e560117a/validity_date=2000/bafc673a9a23494e8539a9196bc99265-0.parquet  -->  trino/ingest/ingest_temp_e560117a/validity_date=2000/bafc673a9a23494e8539a9196bc99265-0.parquet
# /tmp/ingest_temp_e560117a/validity_date=2012/bafc673a9a23494e8539a9196bc99265-0.parquet  -->  trino/ingest/ingest_temp_e560117a/validity_date=2012/bafc673a9a23494e8539a9196bc99265-0.parquet
# /tmp/ingest_temp_e560117a/validity_date=2013/bafc673a9a23494e8539a9196bc99265-0.parquet  -->  trino/ingest/ingest_temp_e560117a/validity_date=2013/bafc673a9a23494e8539a9196bc99265-0.parquet
# /tmp/ingest_temp_e560117a/validity_date=2015/bafc673a9a23494e8539a9196bc99265-0.parquet  -->  trino/ingest/ingest_temp_e560117a/validity_date=2015/bafc673a9a23494e8539a9196bc99265-0.parquet
# /tmp/ingest_temp_e560117a/validity_date=2014/bafc673a9a23494e8539a9196bc99265-0.parquet  -->  trino/ingest/ingest_temp_e560117a/validity_date=2014/bafc673a9a23494e8539a9196bc99265-0.parquet
# /tmp/ingest_temp_e560117a/validity_date=2016/bafc673a9a23494e8539a9196bc99265-0.parquet  -->  trino/ingest/ingest_temp_e560117a/validity_date=2016/bafc673a9a23494e8539a9196bc99265-0.parquet
# /tmp/ingest_temp_e560117a/validity_date=2017/bafc673a9a23494e8539a9196bc99265-0.parquet  -->  trino/ingest/ingest_temp_e560117a/validity_date=2017/bafc673a9a23494e8539a9196bc99265-0.parquet
# /tmp/ingest_temp_e560117a/validity_date=2018/bafc673a9a23494e8539a9196bc99265-0.parquet  -->  trino/ingest/ingest_temp_e560117a/validity_date=2018/bafc673a9a23494e8539a9196bc99265-0.parquet
# /tmp/ingest_temp_e560117a/validity_date=2019/bafc673a9a23494e8539a9196bc99265-0.parquet  -->  trino/ingest/ingest_temp_e560117a/validity_date=2019/bafc673a9a23494e8539a9196bc99265-0.parquet
# /tmp/ingest_temp_e560117a/validity_date=2020/bafc673a9a23494e8539a9196bc99265-0.parquet  -->  trino/ingest/ingest_temp_e560117a/validity_date=2020/bafc673a9a23494e8539a9196bc99265-0.parquet
# /tmp/ingest_temp_e560117a/validity_date=2021/bafc673a9a23494e8539a9196bc99265-0.parquet  -->  trino/ingest/ingest_temp_e560117a/validity_date=2021/bafc673a9a23494e8539a9196bc99265-0.parquet
#
# declaring intermediate hive table osc_datacommons_hive_ingest.ingest.ingest_temp_e560117a
# create table if not exists osc_datacommons_hive_ingest.ingest.ingest_temp_e560117a (
#     rec_source varchar,
#     data_provider varchar,
#     country_iso_code varchar,
#     country_name varchar,
#     attribute varchar,
#     value varchar,
#     value_units varchar,
#     validity_date varchar
# ) with (
#     format = 'parquet',
#     partitioned_by = array['validity_date'],
#     external_location = 's3a://osc-datacommons-s3-bucket-dev02/trino/ingest/ingest_temp_e560117a/'
# )
#
# syncing partition metadata on intermediate hive table
# call osc_datacommons_hive_ingest.system.sync_partition_metadata('ingest', 'ingest_temp_e560117a', 'FULL')
#
# overwriting data in osc_datacommons_dev.mdt_sandbox.sf_wdi_population_source
# delete from osc_datacommons_dev.mdt_sandbox.sf_wdi_population_source
# [(None,)]
#
# transferring data: osc_datacommons_hive_ingest.ingest.ingest_temp_e560117a -> osc_datacommons_dev.mdt_sandbox.sf_wdi_population_source
# insert into osc_datacommons_dev.mdt_sandbox.sf_wdi_population_source
# select * from osc_datacommons_hive_ingest.ingest.ingest_temp_e560117a
# [(3192,)]
#
# deleting table and data for intermediate table osc_datacommons_hive_ingest.ingest.ingest_temp_e560117a
# [{'ResponseMetadata': {'RequestId': '80QX9M30N3Y1AEAR', 'HostId': 'yflDfvGKskrAAhAj56PpJAf7bAMk1WQV+hMPYhhuIp/rBZjTrtWhNaY7NyU6FL4NkViIy3hSzTU=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'yflDfvGKskrAAhAj56PpJAf7bAMk1WQV+hMPYhhuIp/rBZjTrtWhNaY7NyU6FL4NkViIy3hSzTU=', 'x-amz-request-id': '80QX9M30N3Y1AEAR', 'date': 'Sat, 08 Apr 2023 22:30:43 GMT', 'content-type': 'application/xml', 'transfer-encoding': 'chunked', 'server': 'AmazonS3', 'connection': 'close'}, 'RetryAttempts': 0}, 'Deleted': [{'Key': 'trino/ingest/ingest_temp_e560117a/validity_date=2014/bafc673a9a23494e8539a9196bc99265-0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e560117a/validity_date=2020/bafc673a9a23494e8539a9196bc99265-0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e560117a/validity_date=2017/bafc673a9a23494e8539a9196bc99265-0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e560117a/validity_date=2015/bafc673a9a23494e8539a9196bc99265-0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e560117a/validity_date=2013/bafc673a9a23494e8539a9196bc99265-0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e560117a/validity_date=1990/bafc673a9a23494e8539a9196bc99265-0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e560117a/validity_date=2016/bafc673a9a23494e8539a9196bc99265-0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e560117a/validity_date=2000/bafc673a9a23494e8539a9196bc99265-0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e560117a/validity_date=2012/bafc673a9a23494e8539a9196bc99265-0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e560117a/validity_date=2018/bafc673a9a23494e8539a9196bc99265-0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e560117a/validity_date=2019/bafc673a9a23494e8539a9196bc99265-0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e560117a/validity_date=2021/bafc673a9a23494e8539a9196bc99265-0.parquet'}]}]

# %%
print(f"ingest_table = {ingest_table}")

sql=f"""
select * from {ingest_catalog}.{ingest_schema}.{ingest_table}_source
where country_iso_code='BHS' order by validity_date desc"""
pd.read_sql(sql, engine)
# Out:
# ingest_table = sf_wdi_population
#              rec_source data_provider country_iso_code  country_name
# 0   Population_Data.csv           WDI              BHS  Bahamas, The  \
# 1   Population_Data.csv           WDI              BHS  Bahamas, The
# 2   Population_Data.csv           WDI              BHS  Bahamas, The
# 3   Population_Data.csv           WDI              BHS  Bahamas, The
# 4   Population_Data.csv           WDI              BHS  Bahamas, The
# 5   Population_Data.csv           WDI              BHS  Bahamas, The
# 6   Population_Data.csv           WDI              BHS  Bahamas, The
# 7   Population_Data.csv           WDI              BHS  Bahamas, The
# 8   Population_Data.csv           WDI              BHS  Bahamas, The
# 9   Population_Data.csv           WDI              BHS  Bahamas, The
# 10  Population_Data.csv           WDI              BHS  Bahamas, The
# 11  Population_Data.csv           WDI              BHS  Bahamas, The
#
#             attribute   value value_units validity_date
# 0   Population, total  396914                      2021
# 1   Population, total  393248                      2020
# 2   Population, total  389486                      2019
# 3   Population, total  385635                      2018
# 4   Population, total  381749                      2017
# 5   Population, total  377923                      2016
# 6   Population, total  374200                      2015
# 7   Population, total  370625                      2014
# 8   Population, total  367162                      2013
# 9   Population, total  363581                      2012
# 10  Population, total  298045                      2000
# 11  Population, total  256227                      1990

# %%
osc._do_sql(f"insert into {ingest_schema}.{models_table} values(\'{json.dumps(dbt_dict['models'])}\')", engine, verbose=True)
# Out:
# insert into mdt_sandbox.pcaf_dbt_models values('{"sf_wdi_population": {"description": "\"\\nTotal population is a mid-year population based on the de facto definition of population, which counts all residents regardless of legal status or citizenship.\"", "columns": {"rec_source": {"description": "\"Population_Data.csv\""}, "data_provider": {"description": "\"WDI\"", "tags": ["WDI"]}, "country_iso_code": {"description": "\"ISO-3166 Country Code (alpha_3)\"", "tags": ["ISO"]}, "country_name": {"description": "\"ISO-3166 Country Name\"", "tags": ["ISO"]}, "attribute": {"description": "\"Population, total\""}, "value": {"description": "\"Population\""}, "value_units": {"description": "\"People, whether citizens or not\""}, "validity_date": {"description": "\"Year of measurement\""}}}}')
# [(1,)]
# [(1,)]
