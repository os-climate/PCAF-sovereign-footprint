# %% [markdown]
# <font size="5">Ingest WDI - "Population" data into Trino pipeline</font>

# %%
from dotenv import dotenv_values, load_dotenv
import osc_ingest_trino as osc
import os
import pathlib
import shutil

# %%
dotenv_dir = os.environ.get('CREDENTIAL_DOTENV_DIR', os.environ.get('PWD', '/opt/app-root/src'))
dotenv_path = pathlib.Path(dotenv_dir) / 'credentials.env'
if os.path.exists(dotenv_path):
    load_dotenv(dotenv_path=dotenv_path,override=True)

# %%
# use a catalog that is configured for iceberg

iceberg_catalog = 'osc_datacommons_dev'
iceberg_schema = 'pcaf_sovereign_footprint'
pcaf_table_prefix = ''
iceberg_table = 'sf_wdi_population'

ingest_catalog = 'osc_datacommons_hive_ingest'
ingest_schema = 'ingest'


#ingest_catalog = 'osc_datacommons_dev'
#ingest_schema = 'pcaf_sovereign_footprint'

# %% [markdown]
# Load Environment Variables

# %%
import trino
from sqlalchemy.engine import create_engine

env_var_prefix = 'TRINO'

sqlstring = 'trino://{user}@{host}:{port}/'.format(
    user = os.environ[f'{env_var_prefix}_USER'],
    host = os.environ[f'{env_var_prefix}_HOST'],
    port = os.environ[f'{env_var_prefix}_PORT']
)
sqlargs = {
    'auth': trino.auth.JWTAuthentication(os.environ[f'{env_var_prefix}_PASSWD']),
    'http_scheme': 'https',
    'catalog': 'osc_datacommons_dev'
}
engine = create_engine(sqlstring, connect_args = sqlargs)
connection = engine.connect()

trino_bucket = osc.attach_s3_bucket("S3_DEV")

# %%
import boto3

s3_source = boto3.resource(
    service_name="s3",
    endpoint_url=os.environ['S3_LANDING_ENDPOINT'],
    aws_access_key_id=os.environ['S3_LANDING_ACCESS_KEY'],
    aws_secret_access_key=os.environ['S3_LANDING_SECRET_KEY'],
)
source_bucket = s3_source.Bucket(os.environ['S3_LANDING_BUCKET'])

# %% [markdown]
# Open a Trino connection using JWT for authentication

# %%
# Show available schemas to ensure trino connection is set correctly
schema_read = engine.execute(f'show schemas in {ingest_catalog}')
for row in schema_read.fetchall():
    print(row)
# Out:
# ('aicoe_osc_demo_results',)
# ('default',)
# ('demo_dv',)
# ('dera',)
# ('essd',)
# ('iceberg_demo',)
# ('information_schema',)
# ('ingest',)
# ('mdt_sandbox',)
# ('pcaf_sovereign_footprint',)
# ('rmi',)
# ('sandbox',)
# ('wri_gppd',)

# %% [markdown]
# Load GDP file (updated sporadically from https://data.worldbank.org/indicator/NY.GDP.PCAP.PP.CD)

# %%
import pandas as pd
import openpyxl
import ParseXLS as parser



## GDP
ticker_file = s3_source.Object(os.environ['S3_LANDING_BUCKET'],'PCAF-sovereign-footprint/WDI/Population_Data.csv')
ticker_file.download_file(f'/tmp/Population_Data.csv')

df = parser.process('WDI_population.ini','WDI_population.csv') 

# year values are delivered twice . remove the unnecessary part

df[['validity_date', 'column_to_drop']] = df['validity_date'].str.split(' ', expand=True)

df.drop('column_to_drop', axis=1, inplace=True)


## GDP PPP

#df=df.astype({'validity_date': 'int32'})
df= df.convert_dtypes()
df.info(verbose=True)
df= df[['rec_source','data_provider','country_iso_code','country_name','validity_date','attribute','value','value_units']].dropna(subset=['value'])
#df = df.convert_dtypes()
print(df.info(verbose=True))


#df
# Out:
# WDI_population.ini
# file_list:
# ['/tmp/Population_Data.csv']
# /tmp/Population_Data.csv
# 2
# csv
# /tmp/Population_Dat
# <configparser.ConfigParser object at 0x7f07a2b68fa0>
#            Series Name  Series Code
# 0    Population, total  SP.POP.TOTL  \
# 1    Population, total  SP.POP.TOTL
# 2    Population, total  SP.POP.TOTL
# 3    Population, total  SP.POP.TOTL
# 4    Population, total  SP.POP.TOTL
# ..                 ...          ...
# 261  Population, total  SP.POP.TOTL
# 262  Population, total  SP.POP.TOTL
# 263  Population, total  SP.POP.TOTL
# 264  Population, total  SP.POP.TOTL
# 265  Population, total  SP.POP.TOTL
#
#                                    Country Name Country Code 1990 [YR1990]
# 0                                   Afghanistan          AFG      12412311  \
# 1                                       Albania          ALB       3286542
# 2                                       Algeria          DZA      25758872
# 3                                American Samoa          ASM         47351
# 4                                       Andorra          AND         54508
# ..                                          ...          ...           ...
# 261                          Sub-Saharan Africa          SSF     509451875
# 262  Sub-Saharan Africa (excluding high income)          SSA     509382368
# 263   Sub-Saharan Africa (IDA & IBRD countries)          TSS     509451875
# 264                         Upper middle income          UMC    1926685059
# 265                                       World          WLD    5280062644
#
#     2000 [YR2000] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015]
# 0        20779957      31161378      32269592      33370804      34413603  \
# 1         3089027       2900401       2895092       2889104       2880703
# 2        31042238      37383899      38140135      38923688      39728020
# 3           57816         55669         55717         55791         55806
# 4           65390         82427         80770         79213         77993
# ..            ...           ...           ...           ...           ...
# 261     665327588     917725880     943039474     968958352     995458498
# 262     665246457     917637577     942949525     968866993     995365079
# 263     665327588     917725880     943039474     968958352     995458498
# 264    2154077670    2354967527    2374694434    2394063066    2412687400
# 265    6114324044    7089254548    7175500378    7261846543    7347679005
#
#     2016 [YR2016] 2017 [YR2017] 2018 [YR2018] 2019 [YR2019] 2020 [YR2020]
# 0        35383028      36296111      37171922      38041757      38928341  \
# 1         2876101       2873457       2866376       2854191       2837849
# 2        40551398      41389174      42228415      43053054      43851043
# 3           55739         55617         55461         55312         55197
# 4           77295         76997         77008         77146         77265
# ..            ...           ...           ...           ...           ...
# 261    1022530245    1050162810    1078319512    1106957870    1136046775
# 262    1022435568    1050066967    1078222750    1106860245    1135948313
# 263    1022530245    1050162810    1078319512    1106957870    1136046775
# 264    2431145930    2449903406    2466337061    2480707519    2492597173
# 265    7433650819    7519371102    7602716232    7683806444    7763932702
#
#     2021 [YR2021]
# 0        39835428
# 1         2811666
# 2        44616626
# 3           55103
# 4           77354
# ..            ...
# 261    1165563987
# 262    1165464785
# 263    1165563987
# 264    2501427939
# 265    7836630792
#
# [266 rows x 16 columns]
# ['']
# eval_components
# ['Series Name']
# ['Series Name', 'Series Code', 'Country Name', 'Country Code', '1990 [YR1990]', '2000 [YR2000]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]']
# Series Name
# Index(['column names original:Series Name',
#        'column names original:Series Code',
#        'column names original:Country Name',
#        'column names original:Country Code',
#        'column names original:1990 [YR1990]',
#        'column names original:2000 [YR2000]',
#        'column names original:2012 [YR2012]',
#        'column names original:2013 [YR2013]',
#        'column names original:2014 [YR2014]',
#        'column names original:2015 [YR2015]',
#        'column names original:2016 [YR2016]',
#        'column names original:2017 [YR2017]',
#        'column names original:2018 [YR2018]',
#        'column names original:2019 [YR2019]',
#        'column names original:2020 [YR2020]',
#        'column names original:2021 [YR2021]',
#        'column names original:attribute', 'column names original:units'],
#       dtype='object')
# Index(['column names after rename:Series Name',
#        'column names after rename:Series Code',
#        'column names after rename:country_name',
#        'column names after rename:country_iso_code',
#        'column names after rename:1990 [YR1990]',
#        'column names after rename:2000 [YR2000]',
#        'column names after rename:2012 [YR2012]',
#        'column names after rename:2013 [YR2013]',
#        'column names after rename:2014 [YR2014]',
#        'column names after rename:2015 [YR2015]',
#        'column names after rename:2016 [YR2016]',
#        'column names after rename:2017 [YR2017]',
#        'column names after rename:2018 [YR2018]',
#        'column names after rename:2019 [YR2019]',
#        'column names after rename:2020 [YR2020]',
#        'column names after rename:2021 [YR2021]',
#        'column names after rename:attribute',
#        'column names after rename:units'],
#       dtype='object')
# 266
# 266
# before melt
#                                    country_name country_iso_code
# 0                                   Afghanistan              AFG  \
# 1                                       Albania              ALB
# 2                                       Algeria              DZA
# 3                                American Samoa              ASM
# 4                                       Andorra              AND
# ..                                          ...              ...
# 261                          Sub-Saharan Africa              SSF
# 262  Sub-Saharan Africa (excluding high income)              SSA
# 263   Sub-Saharan Africa (IDA & IBRD countries)              TSS
# 264                         Upper middle income              UMC
# 265                                       World              WLD
#
#     1990 [YR1990] 2000 [YR2000] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014]
# 0        12412311      20779957      31161378      32269592      33370804  \
# 1         3286542       3089027       2900401       2895092       2889104
# 2        25758872      31042238      37383899      38140135      38923688
# 3           47351         57816         55669         55717         55791
# 4           54508         65390         82427         80770         79213
# ..            ...           ...           ...           ...           ...
# 261     509451875     665327588     917725880     943039474     968958352
# 262     509382368     665246457     917637577     942949525     968866993
# 263     509451875     665327588     917725880     943039474     968958352
# 264    1926685059    2154077670    2354967527    2374694434    2394063066
# 265    5280062644    6114324044    7089254548    7175500378    7261846543
#
#     2015 [YR2015] 2016 [YR2016] 2017 [YR2017] 2018 [YR2018] 2019 [YR2019]
# 0        34413603      35383028      36296111      37171922      38041757  \
# 1         2880703       2876101       2873457       2866376       2854191
# 2        39728020      40551398      41389174      42228415      43053054
# 3           55806         55739         55617         55461         55312
# 4           77993         77295         76997         77008         77146
# ..            ...           ...           ...           ...           ...
# 261     995458498    1022530245    1050162810    1078319512    1106957870
# 262     995365079    1022435568    1050066967    1078222750    1106860245
# 263     995458498    1022530245    1050162810    1078319512    1106957870
# 264    2412687400    2431145930    2449903406    2466337061    2480707519
# 265    7347679005    7433650819    7519371102    7602716232    7683806444
#
#     2020 [YR2020] 2021 [YR2021]          attribute units
# 0        38928341      39835428  Population, total
# 1         2837849       2811666  Population, total
# 2        43851043      44616626  Population, total
# 3           55197         55103  Population, total
# 4           77265         77354  Population, total
# ..            ...           ...                ...   ...
# 261    1136046775    1165563987  Population, total
# 262    1135948313    1165464785  Population, total
# 263    1136046775    1165563987  Population, total
# 264    2492597173    2501427939  Population, total
# 265    7763932702    7836630792  Population, total
#
# [266 rows x 16 columns]
# after melt
#      country_iso_code                                country_name
# 0                 AFG                                 Afghanistan  \
# 1                 ALB                                     Albania
# 2                 DZA                                     Algeria
# 3                 ASM                              American Samoa
# 4                 AND                                     Andorra
# ...               ...                                         ...
# 3187              SSF                          Sub-Saharan Africa
# 3188              SSA  Sub-Saharan Africa (excluding high income)
# 3189              TSS   Sub-Saharan Africa (IDA & IBRD countries)
# 3190              UMC                         Upper middle income
# 3191              WLD                                       World
#
#               attribute units           year       value
# 0     Population, total        1990 [YR1990]    12412311
# 1     Population, total        1990 [YR1990]     3286542
# 2     Population, total        1990 [YR1990]    25758872
# 3     Population, total        1990 [YR1990]       47351
# 4     Population, total        1990 [YR1990]       54508
# ...                 ...   ...            ...         ...
# 3187  Population, total        2021 [YR2021]  1165563987
# 3188  Population, total        2021 [YR2021]  1165464785
# 3189  Population, total        2021 [YR2021]  1165563987
# 3190  Population, total        2021 [YR2021]  2501427939
# 3191  Population, total        2021 [YR2021]  7836630792
#
# [3192 rows x 6 columns]
# list columns
# ['country_iso_code', 'country_name', 'attribute', 'units', 'year', 'value']
# ['country_iso_code', 'country_name', 'attribute', 'value_units', 'value', 'rec_source', 'data_provider', 'validity_date']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3192 entries, 0 to 3191
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rec_source        3192 non-null   string
#  1   data_provider     3192 non-null   string
#  2   country_name      3192 non-null   string
#  3   country_iso_code  3192 non-null   string
#  4   validity_date     3192 non-null   string
#  5   attribute         3192 non-null   string
#  6   value             3192 non-null   string
#  7   value_units       3192 non-null   string
# dtypes: string(8)
# memory usage: 199.6 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3192 entries, 0 to 3191
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rec_source        3192 non-null   string
#  1   data_provider     3192 non-null   string
#  2   country_iso_code  3192 non-null   string
#  3   country_name      3192 non-null   string
#  4   validity_date     3192 non-null   string
#  5   attribute         3192 non-null   string
#  6   value             3192 non-null   string
#  7   value_units       3192 non-null   string
# dtypes: string(8)
# memory usage: 199.6 KB
# None

# %%
#%run -i TransposeXLS.py --config WDI.ini --output=WDI.csv

# %%
sql = f"""
drop view if exists {iceberg_catalog}.{iceberg_schema}.{iceberg_table}
"""
print(sql)
qres = engine.execute(sql)
#print(qres.fetchall())
# Out:
# drop view if exists osc_datacommons_dev.pcaf_sovereign_footprint.sf_wdi_population

# %%
import osc_ingest_trino as osc
columnschema = osc.create_table_schema_pairs(df) 

sql = f"""
drop table if exists {iceberg_catalog}.{iceberg_schema}.{iceberg_table}
"""
print(sql)
qres = engine.execute(sql)
#print(qres.fetchall())
# Out:
# drop table if exists osc_datacommons_dev.pcaf_sovereign_footprint.sf_wdi_population
# ---------------------------------------------------------------------------
# TrinoUserError                            Traceback (most recent call last)
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/engine/base.py:1802, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1801     if not evt_handled:
# -> 1802         self.dialect.do_execute(
#    1803             cursor, statement, parameters, context
#    1804         )
#    1806 if self._has_events or self.engine._has_events:
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/sqlalchemy/dialect.py:370, in TrinoDialect.do_execute(self, cursor, statement, parameters, context)
#     367 def do_execute(
#     368     self, cursor: Cursor, statement: str, parameters: Tuple[Any, ...], context: DefaultExecutionContext = None
#     369 ):
# --> 370     cursor.execute(statement, parameters)
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/dbapi.py:515, in Cursor.execute(self, operation, params)
#     513     self._query = trino.client.TrinoQuery(self._request, query=operation,
#     514                                           legacy_primitive_types=self._legacy_primitive_types)
# --> 515     self._iterator = iter(self._query.execute())
#     516 return self
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/client.py:821, in TrinoQuery.execute(self, additional_http_headers)
#     820 while not self.finished and not self.cancelled and len(self._result.rows) == 0:
# --> 821     self._result.rows += self.fetch()
#     822 return self._result
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/client.py:838, in TrinoQuery.fetch(self)
#     837 response = self._request.get(self._request.next_uri)
# --> 838 status = self._request.process(response)
#     839 self._update_state(status)
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/client.py:623, in TrinoRequest.process(self, http_response)
#     622 if "error" in response:
# --> 623     raise self._process_error(response["error"], response.get("id"))
#     625 if constants.HEADER_CLEAR_SESSION in http_response.headers:
#
# TrinoUserError: TrinoUserError(type=USER_ERROR, name=GENERIC_USER_ERROR, message="line 2:1: Table 'osc_datacommons_dev.pcaf_sovereign_footprint.sf_wdi_population' does not exist, but a view with that name exists. Did you mean DROP VIEW osc_datacommons_dev.pcaf_sovereign_footprint.sf_wdi_population?", query_id=20230519_085541_00318_wjhqt)
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Input In [9], in <cell line: 8>()
#       4 sql = f"""
#       5 drop table if exists {iceberg_catalog}.{iceberg_schema}.{iceberg_table}
#       6 """
#       7 print(sql)
# ----> 8 qres = engine.execute(sql)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/util/deprecations.py:401, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     399 if not skip_warning:
#     400     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 401 return fn(*args, **kwargs)
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/engine/base.py:3139, in Engine.execute(self, statement, *multiparams, **params)
#    3121 """Executes the given construct and returns a
#    3122 :class:`_engine.CursorResult`.
#    3123
#    (...)
#    3136
#    3137 """
#    3138 connection = self.connect(close_with_result=True)
# -> 3139 return connection.execute(statement, *multiparams, **params)
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/engine/base.py:1274, in Connection.execute(self, statement, *multiparams, **params)
#    1265 if isinstance(statement, util.string_types):
#    1266     util.warn_deprecated_20(
#    1267         "Passing a string to Connection.execute() is "
#    1268         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    1271         "driver-level SQL string."
#    1272     )
# -> 1274     return self._exec_driver_sql(
#    1275         statement,
#    1276         multiparams,
#    1277         params,
#    1278         _EMPTY_EXECUTION_OPTS,
#    1279         future=False,
#    1280     )
#    1282 try:
#    1283     meth = statement._execute_on_connection
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/engine/base.py:1578, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1568         (
#    1569             statement,
#    1570             distilled_params,
#    (...)
#    1574             statement, distilled_parameters, execution_options
#    1575         )
#    1577 dialect = self.dialect
# -> 1578 ret = self._execute_context(
#    1579     dialect,
#    1580     dialect.execution_ctx_cls._init_statement,
#    1581     statement,
#    1582     distilled_parameters,
#    1583     execution_options,
#    1584     statement,
#    1585     distilled_parameters,
#    1586 )
#    1588 if not future:
#    1589     if self._has_events or self.engine._has_events:
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/engine/base.py:1845, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1842             branched.close()
#    1844 except BaseException as e:
# -> 1845     self._handle_dbapi_exception(
#    1846         e, statement, parameters, cursor, context
#    1847     )
#    1849 return result
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/engine/base.py:2026, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2024     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2025 elif should_wrap:
# -> 2026     util.raise_(
#    2027         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2028     )
#    2029 else:
#    2030     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/engine/base.py:1802, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1800                 break
#    1801     if not evt_handled:
# -> 1802         self.dialect.do_execute(
#    1803             cursor, statement, parameters, context
#    1804         )
#    1806 if self._has_events or self.engine._has_events:
#    1807     self.dispatch.after_cursor_execute(
#    1808         self,
#    1809         cursor,
#    (...)
#    1813         context.executemany,
#    1814     )
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/sqlalchemy/dialect.py:370, in TrinoDialect.do_execute(self, cursor, statement, parameters, context)
#     367 def do_execute(
#     368     self, cursor: Cursor, statement: str, parameters: Tuple[Any, ...], context: DefaultExecutionContext = None
#     369 ):
# --> 370     cursor.execute(statement, parameters)
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/dbapi.py:515, in Cursor.execute(self, operation, params)
#     512 else:
#     513     self._query = trino.client.TrinoQuery(self._request, query=operation,
#     514                                           legacy_primitive_types=self._legacy_primitive_types)
# --> 515     self._iterator = iter(self._query.execute())
#     516 return self
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/client.py:821, in TrinoQuery.execute(self, additional_http_headers)
#     819 # Execute should block until at least one row is received or query is finished or cancelled
#     820 while not self.finished and not self.cancelled and len(self._result.rows) == 0:
# --> 821     self._result.rows += self.fetch()
#     822 return self._result
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/client.py:838, in TrinoQuery.fetch(self)
#     836 """Continue fetching data for the current query_id"""
#     837 response = self._request.get(self._request.next_uri)
# --> 838 status = self._request.process(response)
#     839 self._update_state(status)
#     840 logger.debug(status)
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/client.py:623, in TrinoRequest.process(self, http_response)
#     621 logger.debug("HTTP %s: %s", http_response.status_code, response)
#     622 if "error" in response:
# --> 623     raise self._process_error(response["error"], response.get("id"))
#     625 if constants.HEADER_CLEAR_SESSION in http_response.headers:
#     626     for prop in get_header_values(
#     627         http_response.headers, constants.HEADER_CLEAR_SESSION
#     628     ):
#
# ProgrammingError: (trino.exceptions.TrinoUserError) TrinoUserError(type=USER_ERROR, name=GENERIC_USER_ERROR, message="line 2:1: Table 'osc_datacommons_dev.pcaf_sovereign_footprint.sf_wdi_population' does not exist, but a view with that name exists. Did you mean DROP VIEW osc_datacommons_dev.pcaf_sovereign_footprint.sf_wdi_population?", query_id=20230519_085541_00318_wjhqt)
# [SQL:
# drop table if exists osc_datacommons_dev.pcaf_sovereign_footprint.sf_wdi_population
# ]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
tabledef = f"""
create table if not exists {iceberg_catalog}.{iceberg_schema}.{iceberg_table}(
{columnschema}
) with (
    format = 'ORC',
    partitioning = array['validity_date']
)
"""
print(tabledef)
qres = engine.execute(tabledef)
#print(qres.fetchall())
# Out:
# create table if not exists osc_datacommons_dev.pcaf_sovereign_footprint.sf_wdi_population(
#     rec_source varchar,
#     data_provider varchar,
#     country_iso_code varchar,
#     country_name varchar,
#     validity_date varchar,
#     attribute varchar,
#     value varchar,
#     value_units varchar
# ) with (
#     format = 'ORC',
#     partitioning = array['validity_date']
# )

# %%
# Delete the data for the related attribute 
sql=f"""
delete from {iceberg_catalog}.{iceberg_schema}.{iceberg_table} 
"""
qres = engine.execute(sql)
print(qres.fetchall())
# Out:
# [(None,)]

# %%
sql=f"""
select * from {iceberg_catalog}.{iceberg_schema}.{iceberg_table} 
"""
pd.read_sql(sql, engine)
# Out:
# Empty DataFrame
# Columns: [rec_source, data_provider, country_iso_code, country_name, validity_date, attribute, value, value_units]
# Index: []

# %%
print(ingest_catalog)
#df=df.drop(df[df.country_name=="cote d'ivoire"].index)
df.to_sql(iceberg_table,
           con=engine,
           schema=iceberg_schema,
           if_exists='append',
           index=False,
           method=osc.TrinoBatchInsert(batch_size = 1000, verbose = True))
# Out:
# osc_datacommons_hive_ingest
# constructed fully qualified table name as: "pcaf_sovereign_footprint.sf_wdi_population"
# inserting 1000 records
#   ('Population_Data.csv', 'WDI', 'AFG', 'Afghanistan', '1990', 'Population, total', '12412311', '')
#   ('Population_Data.csv', 'WDI', 'ALB', 'Albania', '1990', 'Population, total', '3286542', '')
#   ('Population_Data.csv', 'WDI', 'DZA', 'Algeria', '1990', 'Population, total', '25758872', '')
#   ...
#   ('Population_Data.csv', 'WDI', 'TUV', 'Tuvalu', '2013', 'Population, total', '10849', '')
# batch insert result: [(1000,)]
# inserting 1000 records
#   ('Population_Data.csv', 'WDI', 'UGA', 'Uganda', '2013', 'Population, total', '35694519', '')
#   ('Population_Data.csv', 'WDI', 'UKR', 'Ukraine', '2013', 'Population, total', '45489648', '')
#   ('Population_Data.csv', 'WDI', 'ARE', 'United Arab Emirates', '2013', 'Population, total', '9197908', '')
#   ...
#   ('Population_Data.csv', 'WDI', 'NRU', 'Nauru', '2017', 'Population, total', '10577', '')
# batch insert result: [(1000,)]
# inserting 1000 records
#   ('Population_Data.csv', 'WDI', 'NPL', 'Nepal', '2017', 'Population, total', '27632682', '')
#   ('Population_Data.csv', 'WDI', 'NLD', 'Netherlands', '2017', 'Population, total', '17131296', '')
#   ('Population_Data.csv', 'WDI', 'NCL', 'New Caledonia', '2017', 'Population, total', '270000', '')
#   ...
#   ('Population_Data.csv', 'WDI', 'DEU', 'Germany', '2021', 'Population, total', '83129285', '')
# batch insert result: [(1000,)]
# inserting 192 records
#   ('Population_Data.csv', 'WDI', 'GHA', 'Ghana', '2021', 'Population, total', '31732128', '')
#   ('Population_Data.csv', 'WDI', 'GIB', 'Gibraltar', '2021', 'Population, total', '33691', '')
#   ('Population_Data.csv', 'WDI', 'GRC', 'Greece', '2021', 'Population, total', '10664568', '')
#   ...
#   ('Population_Data.csv', 'WDI', 'WLD', 'World', '2021', 'Population, total', '7836630792', '')
# batch insert result: [(192,)]

# %%
import pandas as pd
sql=f"""
select * from {iceberg_catalog}.{iceberg_schema}.{iceberg_table} " + " where country_iso_code='BHS' order by validity_date desc"""
pd.read_sql(sql, engine)
# Out:
#              rec_source data_provider country_iso_code  country_name
# 0   Population_Data.csv           WDI              BHS  Bahamas, The  \
# 1   Population_Data.csv           WDI              BHS  Bahamas, The
# 2   Population_Data.csv           WDI              BHS  Bahamas, The
# 3   Population_Data.csv           WDI              BHS  Bahamas, The
# 4   Population_Data.csv           WDI              BHS  Bahamas, The
# 5   Population_Data.csv           WDI              BHS  Bahamas, The
# 6   Population_Data.csv           WDI              BHS  Bahamas, The
# 7   Population_Data.csv           WDI              BHS  Bahamas, The
# 8   Population_Data.csv           WDI              BHS  Bahamas, The
# 9   Population_Data.csv           WDI              BHS  Bahamas, The
# 10  Population_Data.csv           WDI              BHS  Bahamas, The
# 11  Population_Data.csv           WDI              BHS  Bahamas, The
#
#    validity_date          attribute   value value_units
# 0           2021  Population, total  396914
# 1           2020  Population, total  393248
# 2           2019  Population, total  389486
# 3           2018  Population, total  385635
# 4           2017  Population, total  381749
# 5           2016  Population, total  377923
# 6           2015  Population, total  374200
# 7           2014  Population, total  370625
# 8           2013  Population, total  367162
# 9           2012  Population, total  363581
# 10          2000  Population, total  298045
# 11          1990  Population, total  256227

# %%
dbt_dict = {}
dbt_dict['models'] = {}
#hive_bucket = osc.attach_s3_bucket('S3_OSCCL2')
hive_bucket = osc.attach_s3_bucket('S3_HIVE')

# %%
def create_trino_table_and_dbt_metadata(tablename, df, partition_columns=[], custom_meta_content='', custom_meta_fields='', verbose=False):
    iceberg_table = f'{pcaf_table_prefix}{tablename}'
    print ("iceberg_table:"+ iceberg_table)

    if custom_meta_content:
        dbt_models = dbt_dict['models']
        dbt_models[iceberg_table] = dbt_table = { 'description': custom_meta_content['description']}
        if custom_meta_fields:
            dbt_table['columns'] = dbt_columns = (
                { name: {'description': custom_meta_fields[name]['Description'] } for name in custom_meta_fields.keys() }
            )
            for name in custom_meta_fields.keys():
                if 'tags' in custom_meta_fields[name].keys():
                    dbt_columns[name]['tags'] = custom_meta_fields[name]['tags']
    elif custom_meta_fields:
        raise VALUE_ERROR

    drop_table = engine.execute(f"drop table if exists {iceberg_schema}.{iceberg_table}_source")
    #drop_table.fetchall()
    
    osc.fast_pandas_ingest_via_hive(
        df,
        engine,
        iceberg_catalog, iceberg_schema, f"{iceberg_table}_source",
        hive_bucket, ingest_catalog, ingest_schema,
        partition_columns = partition_columns,
        overwrite = True,
        typemap={'datetime64[ns]':'date'},
        verbose = verbose
    )

    with open(f"/opt/app-root/src/PCAF-sovereign-footprint/dbt/pcaf_transform/models/{iceberg_table}.sql", "w", encoding="utf-8") as f:
        print("{{ config(materialized='view', view_security='invoker') }}" + f"""
with source_data as (
    select {', '.join(df.columns)}
    from {iceberg_catalog}.{iceberg_schema}.{iceberg_table}_source
)
select * from source_data

""", file=f)

# %%
def description_is (s):
    return { 'Description': s}

# %%
#shutil.rmtree("/opt/app-root/src/PCAF-sovereign-footprint/dbt/pcaf_transform/models", ignore_errors=True)
#path = "/opt/app-root/src/sovereign-footprint"
#dir_list = os.listdir(path)
#print("Files and directories in '", path, "' :") 
# print the list
#print(dir_list)

os.mkdir("/opt/app-root/src/PCAF-sovereign-footprint/dbt/pcaf_transform/models", mode=0o755)
custom_meta_content = {
    'data provider': df[['data_provider']],
     'description': 'Description',
}
custom_meta_fields= {}
custom_meta_fields['country_iso_code'] = description_is("Country ISO Code")

# %%
create_trino_table_and_dbt_metadata('sf_wdi_population', df, [], custom_meta_content, custom_meta_fields,verbose=True)
# Out:
# iceberg_table:sf_wdi_population
#
# verifying existence of table osc_datacommons_dev.pcaf_sovereign_footprint.sf_wdi_population_source
# create table if not exists osc_datacommons_dev.pcaf_sovereign_footprint.sf_wdi_population_source (
#     rec_source varchar,
#     data_provider varchar,
#     country_iso_code varchar,
#     country_name varchar,
#     validity_date varchar,
#     attribute varchar,
#     value varchar,
#     value_units varchar
# ) with (
#     format = 'parquet'
# )
#
# staging dataframe parquet to s3 osc-datacommons-s3-bucket-dev02
# /tmp/a966daefdd2c42f6b6e6f551273df959.parquet  -->  trino/ingest/ingest_temp_cf339c8c/a966daefdd2c42f6b6e6f551273df959.parquet
#
# declaring intermediate hive table osc_datacommons_hive_ingest.ingest.ingest_temp_cf339c8c
# create table if not exists osc_datacommons_hive_ingest.ingest.ingest_temp_cf339c8c (
#     rec_source varchar,
#     data_provider varchar,
#     country_iso_code varchar,
#     country_name varchar,
#     validity_date varchar,
#     attribute varchar,
#     value varchar,
#     value_units varchar
# ) with (
#     format = 'parquet',
#     external_location = 's3a://osc-datacommons-s3-bucket-dev02/trino/ingest/ingest_temp_cf339c8c/'
# )
# ---------------------------------------------------------------------------
# TrinoUserError                            Traceback (most recent call last)
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/engine/base.py:1802, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1801     if not evt_handled:
# -> 1802         self.dialect.do_execute(
#    1803             cursor, statement, parameters, context
#    1804         )
#    1806 if self._has_events or self.engine._has_events:
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/sqlalchemy/dialect.py:370, in TrinoDialect.do_execute(self, cursor, statement, parameters, context)
#     367 def do_execute(
#     368     self, cursor: Cursor, statement: str, parameters: Tuple[Any, ...], context: DefaultExecutionContext = None
#     369 ):
# --> 370     cursor.execute(statement, parameters)
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/dbapi.py:515, in Cursor.execute(self, operation, params)
#     513     self._query = trino.client.TrinoQuery(self._request, query=operation,
#     514                                           legacy_primitive_types=self._legacy_primitive_types)
# --> 515     self._iterator = iter(self._query.execute())
#     516 return self
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/client.py:821, in TrinoQuery.execute(self, additional_http_headers)
#     820 while not self.finished and not self.cancelled and len(self._result.rows) == 0:
# --> 821     self._result.rows += self.fetch()
#     822 return self._result
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/client.py:838, in TrinoQuery.fetch(self)
#     837 response = self._request.get(self._request.next_uri)
# --> 838 status = self._request.process(response)
#     839 self._update_state(status)
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/client.py:623, in TrinoRequest.process(self, http_response)
#     622 if "error" in response:
# --> 623     raise self._process_error(response["error"], response.get("id"))
#     625 if constants.HEADER_CLEAR_SESSION in http_response.headers:
#
# TrinoUserError: TrinoUserError(type=USER_ERROR, name=PERMISSION_DENIED, message="Access Denied: Cannot create table osc_datacommons_hive_ingest.ingest.ingest_temp_cf339c8c", query_id=20230519_090622_00336_wjhqt)
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 create_trino_table_and_dbt_metadata('sf_wdi_population', df, [], custom_meta_content, custom_meta_fields,verbose=True)
#
# Input In [20], in create_trino_table_and_dbt_metadata(tablename, df, partition_columns, custom_meta_content, custom_meta_fields, verbose)
#      18     drop_table = engine.execute(f"drop table if exists {iceberg_schema}.{iceberg_table}_source")
#      19     #drop_table.fetchall()
# ---> 21     osc.fast_pandas_ingest_via_hive(
#      22         df,
#      23         engine,
#      24         iceberg_catalog, iceberg_schema, f"{iceberg_table}_source",
#      25         hive_bucket, ingest_catalog, ingest_schema,
#      26         partition_columns = partition_columns,
#      27         overwrite = True,
#      28         typemap={'datetime64[ns]':'date'},
#      29         verbose = verbose
#      30     )
#      32     with open(f"/opt/app-root/src/PCAF-sovereign-footprint/dbt/pcaf_transform/models/{iceberg_table}.sql", "w", encoding="utf-8") as f:
#      33         print("{{ config(materialized='view', view_security='invoker') }}" + f"""
#      34 with source_data as (
#      35     select {', '.join(df.columns)}
#    (...)
#      39
#      40 """, file=f)
#
# File /opt/app-root/lib64/python3.8/site-packages/osc_ingest_trino/trino_utils.py:112, in fast_pandas_ingest_via_hive(df, engine, catalog, schema, table, hive_bucket, hive_catalog, hive_schema, partition_columns, overwrite, typemap, colmap, verbose)
#     110     tabledef += f"    partitioned_by = array{partition_columns},\n"
#     111 tabledef += f"    external_location = 's3a://{hive_bucket.name}/trino/{hive_schema}/{hive_table}/'\n)"
# --> 112 _do_sql(tabledef, engine, verbose=verbose)
#     114 if verbose:
#     115     print("\nsyncing partition metadata on intermediate hive table")
#
# File /opt/app-root/lib64/python3.8/site-packages/osc_ingest_trino/trino_utils.py:50, in _do_sql(sql, engine, verbose)
#      48 if verbose:
#      49     print(sql)
# ---> 50 qres = engine.execute(sql)
#      51 res = None
#      52 if qres.returns_rows:
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/util/deprecations.py:401, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     399 if not skip_warning:
#     400     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 401 return fn(*args, **kwargs)
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/engine/base.py:3139, in Engine.execute(self, statement, *multiparams, **params)
#    3121 """Executes the given construct and returns a
#    3122 :class:`_engine.CursorResult`.
#    3123
#    (...)
#    3136
#    3137 """
#    3138 connection = self.connect(close_with_result=True)
# -> 3139 return connection.execute(statement, *multiparams, **params)
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/engine/base.py:1289, in Connection.execute(self, statement, *multiparams, **params)
#    1285     util.raise_(
#    1286         exc.ObjectNotExecutableError(statement), replace_context=err
#    1287     )
#    1288 else:
# -> 1289     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/sql/elements.py:325, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     321 def _execute_on_connection(
#     322     self, connection, multiparams, params, execution_options, _force=False
#     323 ):
#     324     if _force or self.supports_execution:
# --> 325         return connection._execute_clauseelement(
#     326             self, multiparams, params, execution_options
#     327         )
#     328     else:
#     329         raise exc.ObjectNotExecutableError(self)
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/engine/base.py:1481, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1469 compiled_cache = execution_options.get(
#    1470     "compiled_cache", self.engine._compiled_cache
#    1471 )
#    1473 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1474     dialect=dialect,
#    1475     compiled_cache=compiled_cache,
#    (...)
#    1479     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1480 )
# -> 1481 ret = self._execute_context(
#    1482     dialect,
#    1483     dialect.execution_ctx_cls._init_compiled,
#    1484     compiled_sql,
#    1485     distilled_params,
#    1486     execution_options,
#    1487     compiled_sql,
#    1488     distilled_params,
#    1489     elem,
#    1490     extracted_params,
#    1491     cache_hit=cache_hit,
#    1492 )
#    1493 if has_events:
#    1494     self.dispatch.after_execute(
#    1495         self,
#    1496         elem,
#    (...)
#    1500         ret,
#    1501     )
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/engine/base.py:1845, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1842             branched.close()
#    1844 except BaseException as e:
# -> 1845     self._handle_dbapi_exception(
#    1846         e, statement, parameters, cursor, context
#    1847     )
#    1849 return result
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/engine/base.py:2026, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2024     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2025 elif should_wrap:
# -> 2026     util.raise_(
#    2027         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2028     )
#    2029 else:
#    2030     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/engine/base.py:1802, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1800                 break
#    1801     if not evt_handled:
# -> 1802         self.dialect.do_execute(
#    1803             cursor, statement, parameters, context
#    1804         )
#    1806 if self._has_events or self.engine._has_events:
#    1807     self.dispatch.after_cursor_execute(
#    1808         self,
#    1809         cursor,
#    (...)
#    1813         context.executemany,
#    1814     )
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/sqlalchemy/dialect.py:370, in TrinoDialect.do_execute(self, cursor, statement, parameters, context)
#     367 def do_execute(
#     368     self, cursor: Cursor, statement: str, parameters: Tuple[Any, ...], context: DefaultExecutionContext = None
#     369 ):
# --> 370     cursor.execute(statement, parameters)
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/dbapi.py:515, in Cursor.execute(self, operation, params)
#     512 else:
#     513     self._query = trino.client.TrinoQuery(self._request, query=operation,
#     514                                           legacy_primitive_types=self._legacy_primitive_types)
# --> 515     self._iterator = iter(self._query.execute())
#     516 return self
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/client.py:821, in TrinoQuery.execute(self, additional_http_headers)
#     819 # Execute should block until at least one row is received or query is finished or cancelled
#     820 while not self.finished and not self.cancelled and len(self._result.rows) == 0:
# --> 821     self._result.rows += self.fetch()
#     822 return self._result
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/client.py:838, in TrinoQuery.fetch(self)
#     836 """Continue fetching data for the current query_id"""
#     837 response = self._request.get(self._request.next_uri)
# --> 838 status = self._request.process(response)
#     839 self._update_state(status)
#     840 logger.debug(status)
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/client.py:623, in TrinoRequest.process(self, http_response)
#     621 logger.debug("HTTP %s: %s", http_response.status_code, response)
#     622 if "error" in response:
# --> 623     raise self._process_error(response["error"], response.get("id"))
#     625 if constants.HEADER_CLEAR_SESSION in http_response.headers:
#     626     for prop in get_header_values(
#     627         http_response.headers, constants.HEADER_CLEAR_SESSION
#     628     ):
#
# ProgrammingError: (trino.exceptions.TrinoUserError) TrinoUserError(type=USER_ERROR, name=PERMISSION_DENIED, message="Access Denied: Cannot create table osc_datacommons_hive_ingest.ingest.ingest_temp_cf339c8c", query_id=20230519_090622_00336_wjhqt)
# [SQL: create table if not exists osc_datacommons_hive_ingest.ingest.ingest_temp_cf339c8c (
#     rec_source varchar,
#     data_provider varchar,
#     country_iso_code varchar,
#     country_name varchar,
#     validity_date varchar,
#     attribute varchar,
#     value varchar,
#     value_units varchar
# ) with (
#     format = 'parquet',
#     external_location = 's3a://osc-datacommons-s3-bucket-dev02/trino/ingest/ingest_temp_cf339c8c/'
# )]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
dbt_yml = open("/opt/app-root/src/PCAF-sovereign-footprint/dbt/pcaf_transform/models/pcaf_schema.yml", "w", encoding="utf-8")

# %%
print("version: 2", file=dbt_yml)

indent = 0
print("\nmodels:", file=dbt_yml)
indent = indent + 2
for name in dbt_dict['models']:
    model = dbt_dict['models'][name]
    print(f"{' '*indent}- name: {name}", file=dbt_yml)
    indent = indent + 2
    print(f"{' '*indent}description: {model['description']}", file=dbt_yml)
    print(f"\n{' '*indent}columns:", file=dbt_yml)
    indent = indent + 2
    columns = model['columns']
    for col in columns:
        print(f"{' '*indent}- name: {col}", file=dbt_yml)
        indent = indent + 2
        for col_meta in columns[col].keys():
            print(f"{' '*indent}{col_meta}: {columns[col][col_meta]}", file=dbt_yml)
        indent = indent - 2
    print("", file=dbt_yml) # newline comes for free...
    indent = indent - 4
indent = indent - 2
assert(indent==0)

# %%
dbt_yml.close()
