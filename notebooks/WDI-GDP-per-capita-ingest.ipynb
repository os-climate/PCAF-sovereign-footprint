# %% [markdown]
# <font size="5">Ingest WDI - "GDP per capita" data into Trino pipeline</font>

# %%
# 'capture' magic prevents long outputs from spamming your notebook
#%%capture pipoutput

# For loading predefined environment variables from files
# Typically used to load sensitive access credentials
# %pip install python-dotenv

# Standard python package for interacting with S3 buckets
# %pip install boto3

# Interacting with Trino and using Trino with sqlalchemy
# %pip install trino sqlalchemy sqlalchemy-trino

# Pandas and parquet file i/o
# %pip install pandas pyarrow fastparquet

# OS-Climate utilities to make data ingest easier
# %pip install osc-ingest-tools
# Out:
# Requirement already satisfied: python-dotenv in /opt/app-root/lib/python3.8/site-packages (0.20.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: boto3 in /opt/app-root/lib/python3.8/site-packages (1.21.40)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /opt/app-root/lib/python3.8/site-packages (from boto3) (0.5.2)
# Requirement already satisfied: botocore<1.25.0,>=1.24.40 in /opt/app-root/lib/python3.8/site-packages (from boto3) (1.24.40)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/app-root/lib/python3.8/site-packages (from boto3) (1.0.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/app-root/lib/python3.8/site-packages (from botocore<1.25.0,>=1.24.40->boto3) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/app-root/lib/python3.8/site-packages (from botocore<1.25.0,>=1.24.40->boto3) (1.26.9)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.25.0,>=1.24.40->boto3) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: trino in /opt/app-root/lib/python3.8/site-packages (0.306.0)
# Requirement already satisfied: sqlalchemy in /opt/app-root/lib/python3.8/site-packages (1.4.35)
# Requirement already satisfied: sqlalchemy-trino in /opt/app-root/lib/python3.8/site-packages (0.4.1)
# Requirement already satisfied: requests in /opt/app-root/lib/python3.8/site-packages (from trino) (2.27.1)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/app-root/lib/python3.8/site-packages (from sqlalchemy) (1.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.8/site-packages (from requests->trino) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from requests->trino) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.8/site-packages (from requests->trino) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/app-root/lib/python3.8/site-packages (from requests->trino) (1.26.9)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /opt/app-root/lib/python3.8/site-packages (1.4.2)
# Requirement already satisfied: pyarrow in /opt/app-root/lib/python3.8/site-packages (7.0.0)
# Requirement already satisfied: fastparquet in /opt/app-root/lib/python3.8/site-packages (0.8.1)
# Requirement already satisfied: numpy>=1.18.5 in /opt/app-root/lib/python3.8/site-packages (from pandas) (1.22.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/app-root/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.8/site-packages (from pandas) (2022.1)
# Requirement already satisfied: cramjam>=2.3.0 in /opt/app-root/lib/python3.8/site-packages (from fastparquet) (2.5.0)
# Requirement already satisfied: fsspec in /opt/app-root/lib/python3.8/site-packages (from fastparquet) (2022.3.0)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: osc-ingest-tools in /opt/app-root/lib/python3.8/site-packages (0.3.4)
# Requirement already satisfied: sqlalchemy-trino in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (0.4.1)
# Requirement already satisfied: trino in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (0.306.0)
# Requirement already satisfied: pandas in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (1.4.2)
# Requirement already satisfied: boto3 in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (1.21.40)
# Requirement already satisfied: sqlalchemy in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (1.4.35)
# Requirement already satisfied: python-dotenv in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (0.20.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/app-root/lib/python3.8/site-packages (from boto3->osc-ingest-tools) (1.0.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /opt/app-root/lib/python3.8/site-packages (from boto3->osc-ingest-tools) (0.5.2)
# Requirement already satisfied: botocore<1.25.0,>=1.24.40 in /opt/app-root/lib/python3.8/site-packages (from boto3->osc-ingest-tools) (1.24.40)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/app-root/lib/python3.8/site-packages (from pandas->osc-ingest-tools) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in /opt/app-root/lib/python3.8/site-packages (from pandas->osc-ingest-tools) (1.22.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.8/site-packages (from pandas->osc-ingest-tools) (2022.1)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/app-root/lib/python3.8/site-packages (from sqlalchemy->osc-ingest-tools) (1.1.2)
# Requirement already satisfied: requests in /opt/app-root/lib/python3.8/site-packages (from trino->osc-ingest-tools) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/app-root/lib/python3.8/site-packages (from botocore<1.25.0,>=1.24.40->boto3->osc-ingest-tools) (1.26.9)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->osc-ingest-tools) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.8/site-packages (from requests->trino->osc-ingest-tools) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from requests->trino->osc-ingest-tools) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.8/site-packages (from requests->trino->osc-ingest-tools) (3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import dotenv_values, load_dotenv
import osc_ingest_trino as osc
import os
import pathlib

# %% [markdown]
# Load Environment Variables

# %%
dotenv_dir = os.environ.get('CREDENTIAL_DOTENV_DIR', os.environ.get('PWD', '/opt/app-root/src'))
dotenv_path = pathlib.Path(dotenv_dir) / 'credentials.env'
if os.path.exists(dotenv_path):
    load_dotenv(dotenv_path=dotenv_path,override=True)

# %%
# use a catalog that is configured for iceberg
ingest_catalog = 'osc_datacommons_dev'
ingest_schema = 'sandbox'
ingest_table = 'pcaf_wdi_gdp'

# %%
import trino
from sqlalchemy.engine import create_engine

env_var_prefix = 'TRINO'

sqlstring = 'trino://{user}@{host}:{port}/'.format(
    user = os.environ[f'{env_var_prefix}_USER'],
    host = os.environ[f'{env_var_prefix}_HOST'],
    port = os.environ[f'{env_var_prefix}_PORT']
)
sqlargs = {
    'auth': trino.auth.JWTAuthentication(os.environ[f'{env_var_prefix}_PASSWD']),
    'http_scheme': 'https',
    'catalog': 'osc_datacommons_dev'
}
engine = create_engine(sqlstring, connect_args = sqlargs)
connection = engine.connect()

trino_bucket = osc.attach_s3_bucket("S3_DEV")
# Out:
# /opt/app-root/lib64/python3.8/site-packages/sqlalchemy_trino/dialect.py:259: SAWarning: Dialect trino:rest will not make use of SQL compilation caching as it does not set the 'supports_statement_cache' attribute to ``True``.  This can have significant performance implications including some performance degradations in comparison to prior SQLAlchemy versions.  Dialect maintainers should seek to set this attribute to True after appropriate development and testing for SQLAlchemy 1.4 caching support.   Alternatively, this attribute may be set to False which will disable this warning. (Background on this error at: https://sqlalche.me/e/14/cprf)
#   res = connection.execute(sql.text(query)).scalar()

# %%
import boto3

s3_source = boto3.resource(
    service_name="s3",
    endpoint_url=os.environ['S3_LANDING_ENDPOINT'],
    aws_access_key_id=os.environ['S3_LANDING_ACCESS_KEY'],
    aws_secret_access_key=os.environ['S3_LANDING_SECRET_KEY'],
)
source_bucket = s3_source.Bucket(os.environ['S3_LANDING_BUCKET'])

# %% [markdown]
# Open a Trino connection using JWT for authentication

# %%
# make sure schema exists, or table creation below will fail in weird ways
sql = f"""
create schema if not exists {ingest_catalog}.{ingest_schema}
"""
qres = engine.execute(sql)
print(qres.fetchall())
# Out:
# [(True,)]

# %%
# Show available schemas to ensure trino connection is set correctly
schema_read = engine.execute(f'show schemas in {ingest_catalog}')
for row in schema_read.fetchall():
    print(row)
# Out:
# ('default',)
# ('demo_dv',)
# ('iceberg_demo',)
# ('information_schema',)
# ('pcaf_sovereign_footprint',)
# ('sandbox',)

# %% [markdown]
# Load GDP file (updated sporadically from https://data.worldbank.org/indicator/NY.GDP.PCAP.PP.CD)

# %%
import pandas as pd

ticker_file = s3_source.Object(os.environ['S3_LANDING_BUCKET'],'PCAF-sovereign-footprint/WDI/API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv')
ticker_file.download_file(f'/tmp/API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv')
#ticker_df = pd.read_csv(f'/tmp/API_NY.GDP.PCAP.PP.CD_DS2_en_csv_v2.csv',sep=",",skiprows=4)
#ticker_df
# %run TransposeXLS.py --config WDI.ini --output=WDI.csv 
df = pd.read_csv('WDI.csv')
#df = df[df['country_name'] == 'Germany']
#df_germany = df_germany[['data_provider','country_iso_code','validity_date','attribute','value']]
df= df[['rec_source','data_provider','country_iso_code','country_name','validity_date','attribute','value','unit']].dropna(subset=['value'])
df = df.convert_dtypes()
print(df.info(verbose=True))
df
#df
# Out:
# WDI.ini
# file_list:
# ['/tmp/API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv']
# /tmp/API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv
# 2
# csv
# /tmp/API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v
# <configparser.ConfigParser object at 0x7fb46be55eb0>
# ['0', '4']
# eval_components
# ['Indicator Name']
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', 'Unnamed: 65']
# Indicator Name
# 265
# 265
# ['country_iso_code', 'country_name', 'attribute', 'unit', 'year', 'value']
# ['country_iso_code', 'country_name', 'attribute', 'unit', 'value', 'rec_source', 'data_provider', 'validity_date']
# load_to_db:no
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7210 entries, 7950 to 16164
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rec_source        7210 non-null   string
#  1   data_provider     7210 non-null   string
#  2   country_iso_code  7210 non-null   string
#  3   country_name      7210 non-null   string
#  4   validity_date     7210 non-null   string
#  5   attribute         7210 non-null   string
#  6   value             7210 non-null   Float64
#  7   unit              7210 non-null   string
# dtypes: Float64(1), string(7)
# memory usage: 514.0 KB
# None
#                                     rec_source data_provider country_iso_code  \
# 7950   API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv           WDI              ABW
# 7951   API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv           WDI              AFE
# 7953   API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv           WDI              AFW
# 7954   API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv           WDI              AGO
# 7955   API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv           WDI              ALB
# ...                                        ...           ...              ...
# 16159  API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv           WDI              WSM
# 16160  API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv           WDI              XKX
# 16162  API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv           WDI              ZAF
# 16163  API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv           WDI              ZMB
# 16164  API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv           WDI              ZWE
#
#                       country_name validity_date  \
# 7950                         Aruba          1990
# 7951   Africa Eastern and Southern          1990
# 7953    Africa Western and Central          1990
# 7954                        Angola          1990
# 7955                       Albania          1990
# ...                            ...           ...
# 16159                        Samoa          2020
# 16160                       Kosovo          2020
# 16162                 South Africa          2020
# 16163                       Zambia          2020
# 16164                     Zimbabwe          2020
#
#                                 attribute                value         unit
# 7950   GDP, PPP (current international $)     1447708861.20673  current US$
# 7951   GDP, PPP (current international $)  565349520935.696045  current US$
# 7953   GDP, PPP (current international $)  354456408577.700012  current US$
# 7954   GDP, PPP (current international $)   38853486198.221001  current US$
# 7955   GDP, PPP (current international $)     8374478544.59225  current US$
# ...                                   ...                  ...          ...
# 16159  GDP, PPP (current international $)     1342987496.78682  current US$
# 16160  GDP, PPP (current international $)     20217375007.3176  current US$
# 16162  GDP, PPP (current international $)  792398142071.171021  current US$
# 16163  GDP, PPP (current international $)   63564551973.879303  current US$
# 16164  GDP, PPP (current international $)     52575395539.3358  current US$
#
# [7210 rows x 8 columns]

# %%
import osc_ingest_trino as osc
columnschema = osc.create_table_schema_pairs(df) 

sql = f"""
drop table if exists {ingest_catalog}.{ingest_schema}.{ingest_table}
"""
print(sql)
qres = engine.execute(sql)
print(qres.fetchall())
# Out:
# drop table if exists osc_datacommons_dev.sandbox.pcaf_wdi_gdp
#
# [(True,)]

# %%
tabledef = f"""
create table if not exists {ingest_catalog}.{ingest_schema}.{ingest_table}(
{columnschema}
) with (
    format = 'ORC',
    partitioning = array['validity_date']
)
"""
print(tabledef)
qres = engine.execute(tabledef)
print(qres.fetchall())
# Out:
# create table if not exists osc_datacommons_dev.sandbox.pcaf_wdi_gdp(
#     rec_source varchar,
#     data_provider varchar,
#     country_iso_code varchar,
#     country_name varchar,
#     validity_date varchar,
#     attribute varchar,
#     value double,
#     unit varchar
# ) with (
#     format = 'ORC',
#     partitioning = array['validity_date']
# )
#
# [(True,)]

# %%
# Delete all data from our db, so we start with empty table
sql=f"""
delete from {ingest_catalog}.{ingest_schema}.{ingest_table}
"""
qres = engine.execute(sql)
print(qres.fetchall())
# Out:
# [(None,)]

# %%
sql=f"""
select * from {ingest_catalog}.{ingest_schema}.{ingest_table}
"""
pd.read_sql(sql, engine)
# Out:
# Empty DataFrame
# Columns: [rec_source, data_provider, country_iso_code, country_name, validity_date, attribute, value, unit]
# Index: []

# %%
print(ingest_catalog)
#df=df.drop(df[df.country_name=="cote d'ivoire"].index)
df.to_sql(ingest_table,
           con=engine,
           schema=ingest_schema,
           if_exists='append',
           index=False,
           method=osc.TrinoBatchInsert(batch_size = 1000, verbose = True))
# Out:
# osc_datacommons_dev
# constructed fully qualified table name as: "sandbox.pcaf_wdi_gdp"
# inserting 1000 records
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'ABW', 'Aruba', '1990', 'GDP, PPP (current international $)', 1447708861.20673, 'current US$')
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'AFE', 'Africa Eastern and Southern', '1990', 'GDP, PPP (current international $)', 565349520935.696, 'current US$')
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'AFW', 'Africa Western and Central', '1990', 'GDP, PPP (current international $)', 354456408577.7, 'current US$')
#   ...
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'ROU', 'Romania', '1994', 'GDP, PPP (current international $)', 113487054061.437, 'current US$')
# batch insert result: [(1000,)]
# inserting 1000 records
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'RUS', 'Russian Federation', '1994', 'GDP, PPP (current international $)', 851031811041.719, 'current US$')
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'RWA', 'Rwanda', '1994', 'GDP, PPP (current international $)', 2111124100.93335, 'current US$')
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'SAS', 'South Asia', '1994', 'GDP, PPP (current international $)', 1859754965357.76, 'current US$')
#   ...
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'DNK', 'Denmark', '1999', 'GDP, PPP (current international $)', 141846293400.642, 'current US$')
# batch insert result: [(1000,)]
# inserting 1000 records
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'DOM', 'Dominican Republic', '1999', 'GDP, PPP (current international $)', 53520017838.257, 'current US$')
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'DZA', 'Algeria', '1999', 'GDP, PPP (current international $)', 247078725218.762, 'current US$')
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'EAP', 'East Asia & Pacific (excluding high income)', '1999', 'GDP, PPP (current international $)', 5446906132141.11, 'current US$')
#   ...
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'KWT', 'Kuwait', '2003', 'GDP, PPP (current international $)', 147144148591.59, 'current US$')
# batch insert result: [(1000,)]
# inserting 1000 records
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'LAC', 'Latin America & Caribbean (excluding high income)', '2003', 'GDP, PPP (current international $)', 4376180324645.62, 'current US$')
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'LAO', 'Lao PDR', '2003', 'GDP, PPP (current international $)', 12251831520.4986, 'current US$')
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'LBN', 'Lebanon', '2003', 'GDP, PPP (current international $)', 40325090855.3231, 'current US$')
#   ...
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'NRU', 'Nauru', '2007', 'GDP, PPP (current international $)', 38801879.8508849, 'current US$')
# batch insert result: [(1000,)]
# inserting 1000 records
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'NZL', 'New Zealand', '2007', 'GDP, PPP (current international $)', 124052195848.734, 'current US$')
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'OED', 'OECD members', '2007', 'GDP, PPP (current international $)', 42054397219570.0, 'current US$')
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'OMN', 'Oman', '2007', 'GDP, PPP (current international $)', 126452739122.173, 'current US$')
#   ...
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'SST', 'Small states', '2011', 'GDP, PPP (current international $)', 762822501991.766, 'current US$')
# batch insert result: [(1000,)]
# inserting 1000 records
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'STP', 'Sao Tome and Principe', '2011', 'GDP, PPP (current international $)', 553046576.228346, 'current US$')
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'SUR', 'Suriname', '2011', 'GDP, PPP (current international $)', 7746725931.88615, 'current US$')
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'SVK', 'Slovak Republic', '2011', 'GDP, PPP (current international $)', 141145550910.631, 'current US$')
#   ...
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'UMC', 'Upper middle income', '2015', 'GDP, PPP (current international $)', 36414550635763.9, 'current US$')
# batch insert result: [(1000,)]
# inserting 1000 records
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'URY', 'Uruguay', '2015', 'GDP, PPP (current international $)', 68982579037.8424, 'current US$')
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'USA', 'United States', '2015', 'GDP, PPP (current international $)', 18238300569000.0, 'current US$')
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'UZB', 'Uzbekistan', '2015', 'GDP, PPP (current international $)', 209082432928.014, 'current US$')
#   ...
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'BRA', 'Brazil', '2020', 'GDP, PPP (current international $)', 3153407029131.61, 'current US$')
# batch insert result: [(1000,)]
# inserting 210 records
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'BRB', 'Barbados', '2020', 'GDP, PPP (current international $)', 3836279388.58695, 'current US$')
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'BRN', 'Brunei Darussalam', '2020', 'GDP, PPP (current international $)', 28704441736.3112, 'current US$')
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'BTN', 'Bhutan', '2020', 'GDP, PPP (current international $)', 8588208404.93795, 'current US$')
#   ...
#   ('API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv', 'WDI', 'ZWE', 'Zimbabwe', '2020', 'GDP, PPP (current international $)', 52575395539.3358, 'current US$')
# batch insert result: [(210,)]

# %%
sql=f"""
select * from {ingest_catalog}.{ingest_schema}.{ingest_table}" + "where validity_date='2007'"""
pd.read_sql(sql, engine)
# Out:
#                                   rec_source data_provider country_iso_code  \
# 0    API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv           WDI              NZL
# 1    API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv           WDI              OED
# 2    API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv           WDI              OMN
# 3    API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv           WDI              OSS
# 4    API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv           WDI              PAK
# ..                                       ...           ...              ...
# 234  API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv           WDI              LCN
# 235  API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv           WDI              LDC
# 236  API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv           WDI              LIC
# 237  API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv           WDI              LKA
# 238  API_NY.GDP.MKTP.PP.CD_DS2_en_csv_v2.csv           WDI              LMC
#
#                                      country_name validity_date  \
# 0                                     New Zealand          2007
# 1                                    OECD members          2007
# 2                                            Oman          2007
# 3                              Other small states          2007
# 4                                        Pakistan          2007
# ..                                            ...           ...
# 234                     Latin America & Caribbean          2007
# 235  Least developed countries: UN classification          2007
# 236                                    Low income          2007
# 237                                     Sri Lanka          2007
# 238                           Lower middle income          2007
#
#                               attribute         value         unit
# 0    GDP, PPP (current international $)  1.240522e+11  current US$
# 1    GDP, PPP (current international $)  4.205440e+13  current US$
# 2    GDP, PPP (current international $)  1.264527e+11  current US$
# 3    GDP, PPP (current international $)  4.567513e+11  current US$
# 4    GDP, PPP (current international $)  6.321089e+11  current US$
# ..                                  ...           ...          ...
# 234  GDP, PPP (current international $)  6.889557e+12  current US$
# 235  GDP, PPP (current international $)  1.464202e+12  current US$
# 236  GDP, PPP (current international $)  6.661773e+11  current US$
# 237  GDP, PPP (current international $)  1.348335e+11  current US$
# 238  GDP, PPP (current international $)  1.232027e+13  current US$
#
# [239 rows x 8 columns]
