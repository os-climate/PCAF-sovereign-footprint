# %%
# 'capture' magic prevents long outputs from spamming your notebook
#%%capture pipoutput
# %pip install xlwt
# %pip install matplotlib
# %pip install pycountry
# For loading predefined environment variables from files
# Typically used to load sensitive access credentials
# %pip install python-dotenv

# Standard python package for interacting with S3 buckets
# %pip install boto3

# Interacting with Trino and using Trino with sqlalchemy
# %pip install trino sqlalchemy sqlalchemy-trino

# Pandas and parquet file i/o
# %pip install pandas pyarrow fastparquet

# OS-Climate utilities to make data ingest easier
# %pip install osc-ingest-tools
#%pip install osc-ingest-trino
# %pip install openpyxl
# %pip install country_converter
# %pip install pint_pandas
# %pip install openscm_units
# %pip install pint
# %pip install --upgrade tzlocal
# Out:
# Collecting xlwt
#   Downloading xlwt-1.3.0-py2.py3-none-any.whl (99 kB)
#      |████████████████████████████████| 99 kB 32.8 MB/s eta 0:00:01
# Installing collected packages: xlwt
# Successfully installed xlwt-1.3.0
# WARNING: You are using pip version 21.1.3; however, version 24.1.2 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /opt/app-root/lib/python3.8/site-packages (3.4.2)
# Requirement already satisfied: numpy>=1.16 in /opt/app-root/lib/python3.8/site-packages (from matplotlib) (1.21.0)
# Requirement already satisfied: cycler>=0.10 in /opt/app-root/lib/python3.8/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/app-root/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/app-root/lib/python3.8/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/app-root/lib/python3.8/site-packages (from matplotlib) (8.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/app-root/lib/python3.8/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: six in /opt/app-root/lib/python3.8/site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# WARNING: You are using pip version 21.1.3; however, version 24.1.2 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting pycountry
#   Downloading pycountry-24.6.1-py3-none-any.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 23.1 MB/s eta 0:00:01
# Collecting importlib-resources>5.12.0
#   Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: zipp>=3.1.0 in /opt/app-root/lib/python3.8/site-packages (from importlib-resources>5.12.0->pycountry) (3.4.1)
# Installing collected packages: importlib-resources, pycountry
# Successfully installed importlib-resources-6.4.0 pycountry-24.6.1
# WARNING: You are using pip version 21.1.3; however, version 24.1.2 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1
# WARNING: You are using pip version 21.1.3; however, version 24.1.2 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: boto3 in /opt/app-root/lib/python3.8/site-packages (1.17.11)
# Requirement already satisfied: botocore<1.21.0,>=1.20.11 in /opt/app-root/lib/python3.8/site-packages (from boto3) (1.20.101)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/app-root/lib/python3.8/site-packages (from boto3) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /opt/app-root/lib/python3.8/site-packages (from boto3) (0.3.7)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/app-root/lib/python3.8/site-packages (from botocore<1.21.0,>=1.20.11->boto3) (1.26.6)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/app-root/lib/python3.8/site-packages (from botocore<1.21.0,>=1.20.11->boto3) (2.8.1)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.21.0,>=1.20.11->boto3) (1.16.0)
# WARNING: You are using pip version 21.1.3; however, version 24.1.2 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting trino
#   Downloading trino-0.329.0-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 19.8 MB/s eta 0:00:01
# Requirement already satisfied: sqlalchemy in /opt/app-root/lib/python3.8/site-packages (1.4.19)
# Collecting sqlalchemy-trino
#   Downloading sqlalchemy_trino-0.5.0-py3-none-any.whl (6.8 kB)
# Requirement already satisfied: tzlocal in /opt/app-root/lib/python3.8/site-packages (from trino) (2.1)
# Collecting backports.zoneinfo
#   Downloading backports.zoneinfo-0.2.1-cp38-cp38-manylinux1_x86_64.whl (74 kB)
#      |████████████████████████████████| 74 kB 99.7 MB/s  eta 0:00:01
# Collecting requests>=2.31.0
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 101.3 MB/s eta 0:00:01
# Requirement already satisfied: pytz in /opt/app-root/lib/python3.8/site-packages (from trino) (2021.1)
# Requirement already satisfied: python-dateutil in /opt/app-root/lib/python3.8/site-packages (from trino) (2.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.31.0->trino) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.31.0->trino) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.31.0->trino) (1.26.6)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#      |████████████████████████████████| 141 kB 123.5 MB/s eta 0:00:01
# Requirement already satisfied: greenlet!=0.4.17 in /opt/app-root/lib/python3.8/site-packages (from sqlalchemy) (1.1.0)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil->trino) (1.16.0)
# Installing collected packages: charset-normalizer, requests, backports.zoneinfo, trino, sqlalchemy-trino
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thoth-python 0.16.1 requires beautifulsoup4==4.6.3, but you have beautifulsoup4 4.9.3 which is incompatible.
# Successfully installed backports.zoneinfo-0.2.1 charset-normalizer-3.3.2 requests-2.32.3 sqlalchemy-trino-0.5.0 trino-0.329.0
# WARNING: You are using pip version 21.1.3; however, version 24.1.2 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /opt/app-root/lib/python3.8/site-packages (1.2.5)
# Requirement already satisfied: pyarrow in /opt/app-root/lib/python3.8/site-packages (4.0.1)
# Collecting fastparquet
#   Downloading fastparquet-2024.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 23.7 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.16.5 in /opt/app-root/lib/python3.8/site-packages (from pandas) (1.21.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/app-root/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/app-root/lib/python3.8/site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Collecting pandas
#   Downloading pandas-2.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#      |████████████████████████████████| 12.4 MB 108.7 MB/s eta 0:00:01
# Collecting cramjam>=2.3
#   Downloading cramjam-2.8.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 108.8 MB/s eta 0:00:01
# Requirement already satisfied: fsspec in /opt/app-root/lib/python3.8/site-packages (from fastparquet) (2021.6.1)
# Requirement already satisfied: packaging in /opt/app-root/lib/python3.8/site-packages (from fastparquet) (20.9)
# Collecting python-dateutil>=2.7.3
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#      |████████████████████████████████| 229 kB 130.5 MB/s eta 0:00:01
# Collecting tzdata>=2022.1
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      |████████████████████████████████| 345 kB 126.0 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/app-root/lib/python3.8/site-packages (from packaging->fastparquet) (2.4.7)
# Installing collected packages: tzdata, python-dateutil, pandas, cramjam, fastparquet
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.1
#     Uninstalling python-dateutil-2.8.1:
#       Successfully uninstalled python-dateutil-2.8.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.5
#     Uninstalling pandas-1.2.5:
#       Successfully uninstalled pandas-1.2.5
# Successfully installed cramjam-2.8.3 fastparquet-2024.2.0 pandas-2.0.3 python-dateutil-2.9.0.post0 tzdata-2024.1
# WARNING: You are using pip version 21.1.3; however, version 24.1.2 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting osc-ingest-tools
#   Downloading osc_ingest_tools-0.5.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: trino[sqlalchemy]>=0.323 in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (0.329.0)
# Collecting sqlalchemy>=2.0
#   Downloading SQLAlchemy-2.0.31-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 38.2 MB/s eta 0:00:01
# Requirement already satisfied: boto3 in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (1.17.11)
# Requirement already satisfied: pandas in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (2.0.3)
# Requirement already satisfied: python-dotenv in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (1.0.1)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/app-root/lib/python3.8/site-packages (from sqlalchemy>=2.0->osc-ingest-tools) (1.1.0)
# Collecting typing-extensions>=4.6.0
#   Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: backports.zoneinfo in /opt/app-root/lib/python3.8/site-packages (from trino[sqlalchemy]>=0.323->osc-ingest-tools) (0.2.1)
# Requirement already satisfied: requests>=2.31.0 in /opt/app-root/lib/python3.8/site-packages (from trino[sqlalchemy]>=0.323->osc-ingest-tools) (2.32.3)
# Requirement already satisfied: pytz in /opt/app-root/lib/python3.8/site-packages (from trino[sqlalchemy]>=0.323->osc-ingest-tools) (2021.1)
# Requirement already satisfied: tzlocal in /opt/app-root/lib/python3.8/site-packages (from trino[sqlalchemy]>=0.323->osc-ingest-tools) (2.1)
# Requirement already satisfied: python-dateutil in /opt/app-root/lib/python3.8/site-packages (from trino[sqlalchemy]>=0.323->osc-ingest-tools) (2.9.0.post0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.31.0->trino[sqlalchemy]>=0.323->osc-ingest-tools) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.31.0->trino[sqlalchemy]>=0.323->osc-ingest-tools) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.31.0->trino[sqlalchemy]>=0.323->osc-ingest-tools) (1.26.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.31.0->trino[sqlalchemy]>=0.323->osc-ingest-tools) (3.3.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/app-root/lib/python3.8/site-packages (from boto3->osc-ingest-tools) (0.10.0)
# Requirement already satisfied: botocore<1.21.0,>=1.20.11 in /opt/app-root/lib/python3.8/site-packages (from boto3->osc-ingest-tools) (1.20.101)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /opt/app-root/lib/python3.8/site-packages (from boto3->osc-ingest-tools) (0.3.7)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil->trino[sqlalchemy]>=0.323->osc-ingest-tools) (1.16.0)
# Requirement already satisfied: numpy>=1.20.3 in /opt/app-root/lib/python3.8/site-packages (from pandas->osc-ingest-tools) (1.21.0)
# Requirement already satisfied: tzdata>=2022.1 in /opt/app-root/lib/python3.8/site-packages (from pandas->osc-ingest-tools) (2024.1)
# Installing collected packages: typing-extensions, sqlalchemy, osc-ingest-tools
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.0
#     Uninstalling typing-extensions-3.10.0.0:
#       Successfully uninstalled typing-extensions-3.10.0.0
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.19
#     Uninstalling SQLAlchemy-1.4.19:
#       Successfully uninstalled SQLAlchemy-1.4.19
# Successfully installed osc-ingest-tools-0.5.2 sqlalchemy-2.0.31 typing-extensions-4.12.2
# WARNING: You are using pip version 21.1.3; however, version 24.1.2 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#      |████████████████████████████████| 250 kB 27.2 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.5
# WARNING: You are using pip version 21.1.3; however, version 24.1.2 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting country_converter
#   Downloading country_converter-1.2-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 26.0 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=1.0 in /opt/app-root/lib/python3.8/site-packages (from country_converter) (2.0.3)
# Requirement already satisfied: numpy>=1.20.3 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.0->country_converter) (1.21.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.0->country_converter) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.0->country_converter) (2021.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.0->country_converter) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas>=1.0->country_converter) (1.16.0)
# Installing collected packages: country-converter
# Successfully installed country-converter-1.2
# WARNING: You are using pip version 21.1.3; however, version 24.1.2 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting pint_pandas
#   Downloading Pint_Pandas-0.3-py2.py3-none-any.whl (23 kB)
# Collecting pint>=0.20.1
#   Downloading Pint-0.21.1-py3-none-any.whl (290 kB)
#      |████████████████████████████████| 290 kB 38.0 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=1.5 in /opt/app-root/lib/python3.8/site-packages (from pint_pandas) (2.0.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.5->pint_pandas) (2021.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.5->pint_pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.5->pint_pandas) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.20.3 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.5->pint_pandas) (1.21.0)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas>=1.5->pint_pandas) (1.16.0)
# Installing collected packages: pint, pint-pandas
# Successfully installed pint-0.21.1 pint-pandas-0.3
# WARNING: You are using pip version 21.1.3; however, version 24.1.2 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting openscm_units
#   Downloading openscm_units-0.5.2-py2.py3-none-any.whl (13 kB)
# Collecting globalwarmingpotentials
#   Downloading globalwarmingpotentials-0.11.1-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: pandas in /opt/app-root/lib/python3.8/site-packages (from openscm_units) (2.0.3)
# Requirement already satisfied: pint in /opt/app-root/lib/python3.8/site-packages (from openscm_units) (0.21.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/app-root/lib/python3.8/site-packages (from pandas->openscm_units) (2024.1)
# Requirement already satisfied: numpy>=1.20.3 in /opt/app-root/lib/python3.8/site-packages (from pandas->openscm_units) (1.21.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.8/site-packages (from pandas->openscm_units) (2021.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/app-root/lib/python3.8/site-packages (from pandas->openscm_units) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas->openscm_units) (1.16.0)
# Installing collected packages: globalwarmingpotentials, openscm-units
# Successfully installed globalwarmingpotentials-0.11.1 openscm-units-0.5.2
# WARNING: You are using pip version 21.1.3; however, version 24.1.2 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pint in /opt/app-root/lib/python3.8/site-packages (0.21.1)
# WARNING: You are using pip version 21.1.3; however, version 24.1.2 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tzlocal in /opt/app-root/lib/python3.8/site-packages (2.1)
# Collecting tzlocal
#   Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: backports.zoneinfo in /opt/app-root/lib/python3.8/site-packages (from tzlocal) (0.2.1)
# Installing collected packages: tzlocal
#   Attempting uninstall: tzlocal
#     Found existing installation: tzlocal 2.1
#     Uninstalling tzlocal-2.1:
#       Successfully uninstalled tzlocal-2.1
# Successfully installed tzlocal-5.2
# WARNING: You are using pip version 21.1.3; however, version 24.1.2 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pint==0.20.1
# Out:
# Collecting pint==0.20.1
#   Downloading Pint-0.20.1-py3-none-any.whl (269 kB)
#      |████████████████████████████████| 269 kB 22.9 MB/s eta 0:00:01
# Installing collected packages: pint
#   Attempting uninstall: pint
#     Found existing installation: Pint 0.21.1
#     Uninstalling Pint-0.21.1:
#       Successfully uninstalled Pint-0.21.1
# Successfully installed pint-0.20.1
# WARNING: You are using pip version 21.1.3; however, version 24.1.2 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pint_pandas==0.3
# Out:
# Requirement already satisfied: pint_pandas==0.3 in /opt/app-root/lib/python3.8/site-packages (0.3)
# Requirement already satisfied: pandas>=1.5 in /opt/app-root/lib/python3.8/site-packages (from pint_pandas==0.3) (2.0.3)
# Requirement already satisfied: pint>=0.20.1 in /opt/app-root/lib/python3.8/site-packages (from pint_pandas==0.3) (0.20.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.5->pint_pandas==0.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.5->pint_pandas==0.3) (2021.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.5->pint_pandas==0.3) (2024.1)
# Requirement already satisfied: numpy>=1.20.3 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.5->pint_pandas==0.3) (1.21.0)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas>=1.5->pint_pandas==0.3) (1.16.0)
# WARNING: You are using pip version 21.1.3; however, version 24.1.2 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from openscm_units import unit_registry
from pint import set_application_registry, Quantity
from pint_pandas import PintArray, PintType
# First we create the registry.
ureg = unit_registry
Q_ = ureg.Quantity
ureg.default_format = '~'
ureg.define("CO2e = CO2 = CO2eq")
ureg.define("USD = [currency] ")
ureg.define("EUR = [currency_EUR] ")
ureg.define('Millions=1000000')
set_application_registry(ureg)
