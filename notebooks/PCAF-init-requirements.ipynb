# %%
# 'capture' magic prevents long outputs from spamming your notebook
#%%capture pipoutput
# %pip install xlwt
# %pip install matplotlib
# %pip install pycountry
# For loading predefined environment variables from files
# Typically used to load sensitive access credentials
# %pip install python-dotenv

# Standard python package for interacting with S3 buckets
# %pip install boto3

# Interacting with Trino and using Trino with sqlalchemy
# %pip install trino sqlalchemy sqlalchemy-trino

# Pandas and parquet file i/o
# %pip install pandas pyarrow fastparquet

# OS-Climate utilities to make data ingest easier
# %pip install osc-ingest-tools
# %pip install openpyxl
# %pip install country_converter
# %pip install pint_pandas
# %pip install openscm_units
# %pip install pint
# Out:
# Collecting xlwt
#   Downloading xlwt-1.3.0-py2.py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 74.3 MB/s eta 0:00:00
# Installing collected packages: xlwt
# Successfully installed xlwt-1.3.0
#
# [notice] A new release of pip available: 22.2.2 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting matplotlib
#   Downloading matplotlib-3.7.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 116.4 MB/s eta 0:00:00a 0:00:01
# Collecting numpy>=1.20
#   Downloading numpy-1.24.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 148.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging>=20.0 in /opt/app-root/lib/python3.8/site-packages (from matplotlib) (21.3)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.5.0-cp38-cp38-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 166.8 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/app-root/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 208.2 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.39.3-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 211.4 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/app-root/lib/python3.8/site-packages (from matplotlib) (5.6.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/app-root/lib/python3.8/site-packages (from matplotlib) (3.0.9)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 kB 113.2 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=3.1.0 in /opt/app-root/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.8.1)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, numpy, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.0.7 cycler-0.11.0 fonttools-4.39.3 kiwisolver-1.4.4 matplotlib-3.7.1 numpy-1.24.3 pillow-9.5.0
#
# [notice] A new release of pip available: 22.2.2 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting pycountry
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 186.6 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools in /opt/app-root/lib/python3.8/site-packages (from pycountry) (63.2.0)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (pyproject.toml) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681832 sha256=ce7ab7f6bbe78ccc21b786789365c7bdd2ff5851d04264706c6fa558bc7abd55
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pxu07gzn/wheels/e2/aa/0f/c224e473b464387170b83ca7c66947b4a7e33e8d903a679748
# Successfully built pycountry
# Installing collected packages: pycountry
# Successfully installed pycountry-22.3.5
#
# [notice] A new release of pip available: 22.2.2 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.0
#
# [notice] A new release of pip available: 22.2.2 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting boto3
#   Downloading boto3-1.26.119-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 60.9 MB/s eta 0:00:00
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 172.4 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting botocore<1.30.0,>=1.29.119
#   Downloading botocore-1.29.119-py3-none-any.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 159.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/app-root/lib/python3.8/site-packages (from botocore<1.30.0,>=1.29.119->boto3) (1.26.10)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/app-root/lib/python3.8/site-packages (from botocore<1.30.0,>=1.29.119->boto3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.30.0,>=1.29.119->boto3) (1.16.0)
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.26.119 botocore-1.29.119 jmespath-1.0.1 s3transfer-0.6.0
#
# [notice] A new release of pip available: 22.2.2 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting trino
#   Downloading trino-0.322.0-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 72.8 MB/s eta 0:00:00
# Requirement already satisfied: sqlalchemy in /opt/app-root/lib/python3.8/site-packages (1.4.32)
# Collecting sqlalchemy-trino
#   Downloading sqlalchemy_trino-0.5.0-py3-none-any.whl (6.8 kB)
# Requirement already satisfied: pytz in /opt/app-root/lib/python3.8/site-packages (from trino) (2022.1)
# Requirement already satisfied: requests in /opt/app-root/lib/python3.8/site-packages (from trino) (2.28.1)
# Requirement already satisfied: tzlocal in /opt/app-root/lib/python3.8/site-packages (from trino) (4.1)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/app-root/lib/python3.8/site-packages (from sqlalchemy) (1.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/app-root/lib/python3.8/site-packages (from requests->trino) (1.26.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/app-root/lib/python3.8/site-packages (from requests->trino) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.8/site-packages (from requests->trino) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.8/site-packages (from requests->trino) (3.3)
# Requirement already satisfied: pytz-deprecation-shim in /opt/app-root/lib/python3.8/site-packages (from tzlocal->trino) (0.1.0.post0)
# Requirement already satisfied: backports.zoneinfo in /opt/app-root/lib/python3.8/site-packages (from tzlocal->trino) (0.2.1)
# Requirement already satisfied: tzdata in /opt/app-root/lib/python3.8/site-packages (from pytz-deprecation-shim->tzlocal->trino) (2022.1)
# Installing collected packages: trino, sqlalchemy-trino
# Successfully installed sqlalchemy-trino-0.5.0 trino-0.322.0
#
# [notice] A new release of pip available: 22.2.2 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting pandas
#   Downloading pandas-2.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 165.6 MB/s eta 0:00:0000:0100:01
# Collecting pyarrow
#   Downloading pyarrow-11.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.0/35.0 MB 171.9 MB/s eta 0:00:00a 0:00:01
# Collecting fastparquet
#   Downloading fastparquet-2023.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 207.4 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.8/site-packages (from pandas) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/app-root/lib/python3.8/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.20.3 in /opt/app-root/lib/python3.8/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/app-root/lib/python3.8/site-packages (from pandas) (2.8.2)
# Collecting cramjam>=2.3
#   Downloading cramjam-2.6.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 205.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /opt/app-root/lib/python3.8/site-packages (from fastparquet) (21.3)
# Collecting fsspec
#   Downloading fsspec-2023.4.0-py3-none-any.whl (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.0/154.0 kB 177.2 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/app-root/lib/python3.8/site-packages (from packaging->fastparquet) (3.0.9)
# Installing collected packages: pyarrow, fsspec, cramjam, pandas, fastparquet
# Successfully installed cramjam-2.6.2 fastparquet-2023.2.0 fsspec-2023.4.0 pandas-2.0.1 pyarrow-11.0.0
#
# [notice] A new release of pip available: 22.2.2 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting osc-ingest-tools
#   Downloading osc_ingest_tools-0.4.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: sqlalchemy in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (1.4.32)
# Requirement already satisfied: pandas in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (2.0.1)
# Requirement already satisfied: trino[sqlalchemy] in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (0.322.0)
# Requirement already satisfied: python-dotenv in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (1.0.0)
# Requirement already satisfied: boto3 in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (1.26.119)
# Requirement already satisfied: botocore<1.30.0,>=1.29.119 in /opt/app-root/lib/python3.8/site-packages (from boto3->osc-ingest-tools) (1.29.119)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /opt/app-root/lib/python3.8/site-packages (from boto3->osc-ingest-tools) (0.6.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/app-root/lib/python3.8/site-packages (from boto3->osc-ingest-tools) (1.0.1)
# Requirement already satisfied: numpy>=1.20.3 in /opt/app-root/lib/python3.8/site-packages (from pandas->osc-ingest-tools) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/app-root/lib/python3.8/site-packages (from pandas->osc-ingest-tools) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/app-root/lib/python3.8/site-packages (from pandas->osc-ingest-tools) (2022.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.8/site-packages (from pandas->osc-ingest-tools) (2022.1)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/app-root/lib/python3.8/site-packages (from sqlalchemy->osc-ingest-tools) (1.1.2)
# Requirement already satisfied: tzlocal in /opt/app-root/lib/python3.8/site-packages (from trino[sqlalchemy]->osc-ingest-tools) (4.1)
# Requirement already satisfied: requests in /opt/app-root/lib/python3.8/site-packages (from trino[sqlalchemy]->osc-ingest-tools) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/app-root/lib/python3.8/site-packages (from botocore<1.30.0,>=1.29.119->boto3->osc-ingest-tools) (1.26.10)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas->osc-ingest-tools) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.8/site-packages (from requests->trino[sqlalchemy]->osc-ingest-tools) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/app-root/lib/python3.8/site-packages (from requests->trino[sqlalchemy]->osc-ingest-tools) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.8/site-packages (from requests->trino[sqlalchemy]->osc-ingest-tools) (2022.6.15)
# Requirement already satisfied: pytz-deprecation-shim in /opt/app-root/lib/python3.8/site-packages (from tzlocal->trino[sqlalchemy]->osc-ingest-tools) (0.1.0.post0)
# Requirement already satisfied: backports.zoneinfo in /opt/app-root/lib/python3.8/site-packages (from tzlocal->trino[sqlalchemy]->osc-ingest-tools) (0.2.1)
# Installing collected packages: osc-ingest-tools
# Successfully installed osc-ingest-tools-0.4.3
#
# [notice] A new release of pip available: 22.2.2 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 61.8 MB/s eta 0:00:00
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
#
# [notice] A new release of pip available: 22.2.2 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting country_converter
#   Downloading country_converter-1.0.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 71.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0 in /opt/app-root/lib/python3.8/site-packages (from country_converter) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.0->country_converter) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.0->country_converter) (2022.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.0->country_converter) (2022.1)
# Requirement already satisfied: numpy>=1.20.3 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.0->country_converter) (1.24.3)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas>=1.0->country_converter) (1.16.0)
# Installing collected packages: country_converter
# Successfully installed country_converter-1.0.0
#
# [notice] A new release of pip available: 22.2.2 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting pint_pandas
#   Downloading Pint_Pandas-0.3-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pandas>=1.5 in /opt/app-root/lib/python3.8/site-packages (from pint_pandas) (2.0.1)
# Collecting pint>=0.20.1
#   Downloading Pint-0.20.1-py3-none-any.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.5/269.5 kB 49.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.3 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.5->pint_pandas) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.5->pint_pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.5->pint_pandas) (2022.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.5->pint_pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas>=1.5->pint_pandas) (1.16.0)
# Installing collected packages: pint, pint_pandas
# Successfully installed pint-0.20.1 pint_pandas-0.3
#
# [notice] A new release of pip available: 22.2.2 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting openscm_units
#   Downloading openscm_units-0.5.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: pandas in /opt/app-root/lib/python3.8/site-packages (from openscm_units) (2.0.1)
# Collecting globalwarmingpotentials
#   Downloading globalwarmingpotentials-0.9.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: pint in /opt/app-root/lib/python3.8/site-packages (from openscm_units) (0.20.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/app-root/lib/python3.8/site-packages (from pandas->openscm_units) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/app-root/lib/python3.8/site-packages (from pandas->openscm_units) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in /opt/app-root/lib/python3.8/site-packages (from pandas->openscm_units) (1.24.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.8/site-packages (from pandas->openscm_units) (2022.1)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas->openscm_units) (1.16.0)
# Installing collected packages: globalwarmingpotentials, openscm_units
# Successfully installed globalwarmingpotentials-0.9.3 openscm_units-0.5.0
#
# [notice] A new release of pip available: 22.2.2 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pint in /opt/app-root/lib/python3.8/site-packages (0.20.1)
#
# [notice] A new release of pip available: 22.2.2 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from openscm_units import unit_registry
from pint import set_application_registry, Quantity
from pint_pandas import PintArray, PintType
# First we create the registry.
ureg = unit_registry
Q_ = ureg.Quantity
ureg.default_format = '~'
ureg.define("CO2e = CO2 = CO2eq")
ureg.define("USD = [currency] ")
ureg.define("EUR = [currency_EUR] ")
ureg.define('Millions=1000000')
set_application_registry(ureg)
# Out:
# 2023-03-08 16:06:52,873 [364] WARNING  pint.util: Redefining 'CO2e' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2023-03-08 16:06:52,875 [364] WARNING  pint.util: Redefining 'CO2eq' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2023-03-08 16:06:52,878 [364] WARNING  pint.util: Redefining 'USD' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2023-03-08 16:06:52,880 [364] WARNING  pint.util: Redefining 'EUR' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2023-03-08 16:06:52,883 [364] WARNING  pint.util: Redefining 'Millions' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
