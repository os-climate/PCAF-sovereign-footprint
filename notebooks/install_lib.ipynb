# %%
# 'capture' magic prevents long outputs from spamming your notebook
#%%capture pipoutput

# For loading predefined environment variables from files
# Typically used to load sensitive access credentials
# %pip install python-dotenv

# Standard python package for interacting with S3 buckets
# %pip install boto3
# Interacting with Trino and using Trino with sqlalchemy
# %pip install trino sqlalchemy sqlalchemy-trino

# Pandas and parquet file i/o
# %pip install pandas pyarrow fastparquet

# OS-Climate utilities to make data ingest easier
# %pip install osc-ingest-tools
# %pip install ipython --upgrade
# %pip install country_converter --upgrade
# %pip install pint-pandas
# %pip install openscm-units
# %pip install Pint==0.19.2
# %pip install jedi
# %pip install pycountry
# %pip install openpyxl
# %pip install xlwt
# %pip install dbt-core dbt-trino
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.0
# WARNING: You are using pip version 21.1.3; however, version 23.2.1 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: boto3 in /opt/app-root/lib/python3.8/site-packages (1.17.11)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /opt/app-root/lib/python3.8/site-packages (from boto3) (0.3.7)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/app-root/lib/python3.8/site-packages (from boto3) (0.10.0)
# Requirement already satisfied: botocore<1.21.0,>=1.20.11 in /opt/app-root/lib/python3.8/site-packages (from boto3) (1.20.101)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/app-root/lib/python3.8/site-packages (from botocore<1.21.0,>=1.20.11->boto3) (1.26.6)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/app-root/lib/python3.8/site-packages (from botocore<1.21.0,>=1.20.11->boto3) (2.8.1)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.21.0,>=1.20.11->boto3) (1.16.0)
# WARNING: You are using pip version 21.1.3; however, version 23.2.1 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting trino
#   Downloading trino-0.326.0-py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 29.7 MB/s eta 0:00:01
# Requirement already satisfied: sqlalchemy in /opt/app-root/lib/python3.8/site-packages (1.4.19)
# Collecting sqlalchemy-trino
#   Downloading sqlalchemy_trino-0.5.0-py3-none-any.whl (6.8 kB)
# Requirement already satisfied: python-dateutil in /opt/app-root/lib/python3.8/site-packages (from trino) (2.8.1)
# Requirement already satisfied: pytz in /opt/app-root/lib/python3.8/site-packages (from trino) (2021.1)
# Collecting backports.zoneinfo
#   Downloading backports.zoneinfo-0.2.1-cp38-cp38-manylinux1_x86_64.whl (74 kB)
#      |████████████████████████████████| 74 kB 103.0 MB/s eta 0:00:01
# Collecting requests>=2.31.0
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 76.3 MB/s  eta 0:00:01
# Requirement already satisfied: tzlocal in /opt/app-root/lib/python3.8/site-packages (from trino) (2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.31.0->trino) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.31.0->trino) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.31.0->trino) (1.26.6)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (199 kB)
#      |████████████████████████████████| 199 kB 129.9 MB/s eta 0:00:01
# Requirement already satisfied: greenlet!=0.4.17 in /opt/app-root/lib/python3.8/site-packages (from sqlalchemy) (1.1.0)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil->trino) (1.16.0)
# Installing collected packages: charset-normalizer, requests, backports.zoneinfo, trino, sqlalchemy-trino
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thoth-python 0.16.1 requires beautifulsoup4==4.6.3, but you have beautifulsoup4 4.9.3 which is incompatible.
# Successfully installed backports.zoneinfo-0.2.1 charset-normalizer-3.2.0 requests-2.31.0 sqlalchemy-trino-0.5.0 trino-0.326.0
# WARNING: You are using pip version 21.1.3; however, version 23.2.1 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /opt/app-root/lib/python3.8/site-packages (1.2.5)
# Requirement already satisfied: pyarrow in /opt/app-root/lib/python3.8/site-packages (4.0.1)
# Collecting fastparquet
#   Downloading fastparquet-2023.8.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 27.5 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2017.3 in /opt/app-root/lib/python3.8/site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/app-root/lib/python3.8/site-packages (from pandas) (1.21.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/app-root/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: packaging in /opt/app-root/lib/python3.8/site-packages (from fastparquet) (20.9)
# Collecting cramjam>=2.3
#   Downloading cramjam-2.7.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 134.7 MB/s eta 0:00:01
# Collecting pandas
#   Downloading pandas-2.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#      |████████████████████████████████| 12.4 MB 127.4 MB/s eta 0:00:01
# Requirement already satisfied: fsspec in /opt/app-root/lib/python3.8/site-packages (from fastparquet) (2021.6.1)
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      |████████████████████████████████| 341 kB 130.9 MB/s eta 0:00:01
# Collecting python-dateutil>=2.7.3
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      |████████████████████████████████| 247 kB 129.2 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/app-root/lib/python3.8/site-packages (from packaging->fastparquet) (2.4.7)
# Installing collected packages: tzdata, python-dateutil, pandas, cramjam, fastparquet
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.1
#     Uninstalling python-dateutil-2.8.1:
#       Successfully uninstalled python-dateutil-2.8.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.5
#     Uninstalling pandas-1.2.5:
#       Successfully uninstalled pandas-1.2.5
# Successfully installed cramjam-2.7.0 fastparquet-2023.8.0 pandas-2.0.3 python-dateutil-2.8.2 tzdata-2023.3
# WARNING: You are using pip version 21.1.3; however, version 23.2.1 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting osc-ingest-tools
#   Downloading osc_ingest_tools-0.4.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: trino[sqlalchemy] in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (0.326.0)
# Requirement already satisfied: boto3 in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (1.17.11)
# Requirement already satisfied: pandas in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (2.0.3)
# Requirement already satisfied: python-dotenv in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (1.0.0)
# Requirement already satisfied: sqlalchemy in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (1.4.19)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/app-root/lib/python3.8/site-packages (from boto3->osc-ingest-tools) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /opt/app-root/lib/python3.8/site-packages (from boto3->osc-ingest-tools) (0.3.7)
# Requirement already satisfied: botocore<1.21.0,>=1.20.11 in /opt/app-root/lib/python3.8/site-packages (from boto3->osc-ingest-tools) (1.20.101)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/app-root/lib/python3.8/site-packages (from botocore<1.21.0,>=1.20.11->boto3->osc-ingest-tools) (1.26.6)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/app-root/lib/python3.8/site-packages (from botocore<1.21.0,>=1.20.11->boto3->osc-ingest-tools) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.21.0,>=1.20.11->boto3->osc-ingest-tools) (1.16.0)
# Requirement already satisfied: numpy>=1.20.3 in /opt/app-root/lib/python3.8/site-packages (from pandas->osc-ingest-tools) (1.21.0)
# Requirement already satisfied: tzdata>=2022.1 in /opt/app-root/lib/python3.8/site-packages (from pandas->osc-ingest-tools) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.8/site-packages (from pandas->osc-ingest-tools) (2021.1)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/app-root/lib/python3.8/site-packages (from sqlalchemy->osc-ingest-tools) (1.1.0)
# Requirement already satisfied: tzlocal in /opt/app-root/lib/python3.8/site-packages (from trino[sqlalchemy]->osc-ingest-tools) (2.1)
# Requirement already satisfied: backports.zoneinfo in /opt/app-root/lib/python3.8/site-packages (from trino[sqlalchemy]->osc-ingest-tools) (0.2.1)
# Requirement already satisfied: requests>=2.31.0 in /opt/app-root/lib/python3.8/site-packages (from trino[sqlalchemy]->osc-ingest-tools) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.31.0->trino[sqlalchemy]->osc-ingest-tools) (3.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.31.0->trino[sqlalchemy]->osc-ingest-tools) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.31.0->trino[sqlalchemy]->osc-ingest-tools) (2.10)
# Installing collected packages: osc-ingest-tools
# Successfully installed osc-ingest-tools-0.4.3
# WARNING: You are using pip version 21.1.3; however, version 23.2.1 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipython in /opt/app-root/lib/python3.8/site-packages (7.25.0)
# Collecting ipython
#   Downloading ipython-8.12.2-py3-none-any.whl (797 kB)
#      |████████████████████████████████| 797 kB 25.5 MB/s eta 0:00:01
# Requirement already satisfied: pygments>=2.4.0 in /opt/app-root/lib/python3.8/site-packages (from ipython) (2.9.0)
# Requirement already satisfied: decorator in /opt/app-root/lib/python3.8/site-packages (from ipython) (4.4.2)
# Requirement already satisfied: pickleshare in /opt/app-root/lib/python3.8/site-packages (from ipython) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /opt/app-root/lib/python3.8/site-packages (from ipython) (4.8.0)
# Collecting prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30
#   Downloading prompt_toolkit-3.0.39-py3-none-any.whl (385 kB)
#      |████████████████████████████████| 385 kB 136.7 MB/s eta 0:00:01
# Requirement already satisfied: jedi>=0.16 in /opt/app-root/lib/python3.8/site-packages (from ipython) (0.17.2)
# Requirement already satisfied: backcall in /opt/app-root/lib/python3.8/site-packages (from ipython) (0.2.0)
# Collecting stack-data
#   Downloading stack_data-0.6.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: traitlets>=5 in /opt/app-root/lib/python3.8/site-packages (from ipython) (5.0.5)
# Requirement already satisfied: typing-extensions in /opt/app-root/lib/python3.8/site-packages (from ipython) (3.10.0.0)
# Requirement already satisfied: matplotlib-inline in /opt/app-root/lib/python3.8/site-packages (from ipython) (0.1.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /opt/app-root/lib/python3.8/site-packages (from jedi>=0.16->ipython) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/app-root/lib/python3.8/site-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/app-root/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython) (0.2.5)
# Requirement already satisfied: ipython-genutils in /opt/app-root/lib/python3.8/site-packages (from traitlets>=5->ipython) (0.2.0)
# Collecting executing>=1.2.0
#   Downloading executing-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting pure-eval
#   Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Collecting asttokens>=2.1.0
#   Downloading asttokens-2.4.0-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: six>=1.12.0 in /opt/app-root/lib/python3.8/site-packages (from asttokens>=2.1.0->stack-data->ipython) (1.16.0)
# Installing collected packages: pure-eval, executing, asttokens, stack-data, prompt-toolkit, ipython
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.19
#     Uninstalling prompt-toolkit-3.0.19:
#       Successfully uninstalled prompt-toolkit-3.0.19
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.25.0
#     Uninstalling ipython-7.25.0:
#       Successfully uninstalled ipython-7.25.0
# Successfully installed asttokens-2.4.0 executing-1.2.0 ipython-8.12.2 prompt-toolkit-3.0.39 pure-eval-0.2.2 stack-data-0.6.2
# WARNING: You are using pip version 21.1.3; however, version 23.2.1 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting country_converter
#   Downloading country_converter-1.0.0-py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 25.0 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=1.0 in /opt/app-root/lib/python3.8/site-packages (from country_converter) (2.0.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.0->country_converter) (2021.1)
# Requirement already satisfied: numpy>=1.20.3 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.0->country_converter) (1.21.0)
# Requirement already satisfied: tzdata>=2022.1 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.0->country_converter) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.0->country_converter) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas>=1.0->country_converter) (1.16.0)
# Installing collected packages: country-converter
# Successfully installed country-converter-1.0.0
# WARNING: You are using pip version 21.1.3; however, version 23.2.1 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting pint-pandas
#   Downloading Pint_Pandas-0.3-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pandas>=1.5 in /opt/app-root/lib/python3.8/site-packages (from pint-pandas) (2.0.3)
# Collecting pint>=0.20.1
#   Downloading Pint-0.21.1-py3-none-any.whl (290 kB)
#      |████████████████████████████████| 290 kB 47.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.20.3 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.5->pint-pandas) (1.21.0)
# Requirement already satisfied: tzdata>=2022.1 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.5->pint-pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.5->pint-pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.5->pint-pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas>=1.5->pint-pandas) (1.16.0)
# Installing collected packages: pint, pint-pandas
# Successfully installed pint-0.21.1 pint-pandas-0.3
# WARNING: You are using pip version 21.1.3; however, version 23.2.1 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting openscm-units
#   Downloading openscm_units-0.5.2-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: pandas in /opt/app-root/lib/python3.8/site-packages (from openscm-units) (2.0.3)
# Collecting globalwarmingpotentials
#   Downloading globalwarmingpotentials-0.9.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: pint in /opt/app-root/lib/python3.8/site-packages (from openscm-units) (0.21.1)
# Requirement already satisfied: numpy>=1.20.3 in /opt/app-root/lib/python3.8/site-packages (from pandas->openscm-units) (1.21.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.8/site-packages (from pandas->openscm-units) (2021.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/app-root/lib/python3.8/site-packages (from pandas->openscm-units) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/app-root/lib/python3.8/site-packages (from pandas->openscm-units) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas->openscm-units) (1.16.0)
# Installing collected packages: globalwarmingpotentials, openscm-units
# Successfully installed globalwarmingpotentials-0.9.3 openscm-units-0.5.2
# WARNING: You are using pip version 21.1.3; however, version 23.2.1 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting Pint==0.19.2
#   Downloading Pint-0.19.2.tar.gz (292 kB)
#      |████████████████████████████████| 292 kB 26.8 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Building wheels for collected packages: Pint
#   Building wheel for Pint (PEP 517) ... done
#   Created wheel for Pint: filename=Pint-0.19.2-py3-none-any.whl size=230998 sha256=bdb32c220a4c18e463eff17c88f28e93fd61f994bd5842630ddaad6c6ac99055
#   Stored in directory: /tmp/pip-ephem-wheel-cache-z5yee2ly/wheels/98/1d/e0/a44541f5302ac50028a3be0db9417c18092c61f25009d62145
# Successfully built Pint
# Installing collected packages: Pint
#   Attempting uninstall: Pint
#     Found existing installation: Pint 0.21.1
#     Uninstalling Pint-0.21.1:
#       Successfully uninstalled Pint-0.21.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pint-pandas 0.3 requires pint>=0.20.1, but you have pint 0.19.2 which is incompatible.
# Successfully installed Pint-0.19.2
# WARNING: You are using pip version 21.1.3; however, version 23.2.1 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: jedi in /opt/app-root/lib/python3.8/site-packages (0.17.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /opt/app-root/lib/python3.8/site-packages (from jedi) (0.7.1)
# WARNING: You are using pip version 21.1.3; however, version 23.2.1 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting pycountry
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      |████████████████████████████████| 10.1 MB 27.3 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: setuptools in /opt/app-root/lib/python3.8/site-packages (from pycountry) (57.0.0)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (PEP 517) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681833 sha256=67aaa37fcfc7d39627a2f7d81d77d26fa62b8f24a65ad980bd27e839c82663a5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dk8kpnpf/wheels/e2/aa/0f/c224e473b464387170b83ca7c66947b4a7e33e8d903a679748
# Successfully built pycountry
# Installing collected packages: pycountry
# Successfully installed pycountry-22.3.5
# WARNING: You are using pip version 21.1.3; however, version 23.2.1 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      |████████████████████████████████| 249 kB 25.7 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
# WARNING: You are using pip version 21.1.3; however, version 23.2.1 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting xlwt
#   Downloading xlwt-1.3.0-py2.py3-none-any.whl (99 kB)
#      |████████████████████████████████| 99 kB 24.1 MB/s eta 0:00:01
# Installing collected packages: xlwt
# Successfully installed xlwt-1.3.0
# WARNING: You are using pip version 21.1.3; however, version 23.2.1 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting dbt-core
#   Downloading dbt_core-1.6.2-py3-none-any.whl (992 kB)
#      |████████████████████████████████| 992 kB 24.2 MB/s eta 0:00:01
# Collecting dbt-trino
#   Downloading dbt_trino-1.6.1-py3-none-any.whl (32 kB)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /opt/app-root/lib/python3.8/site-packages (from dbt-core) (1.14.5)
# Collecting logbook<1.6,>=1.5
#   Downloading Logbook-1.5.3.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 111.5 MB/s eta 0:00:01
# Collecting minimal-snowplow-tracker~=0.0.2
#   Downloading minimal-snowplow-tracker-0.0.2.tar.gz (12 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in /opt/app-root/lib/python3.8/site-packages (from dbt-core) (3.10.0.0)
# Collecting protobuf>=4.0.0
#   Downloading protobuf-4.24.3-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
#      |████████████████████████████████| 311 kB 115.4 MB/s eta 0:00:01
# Collecting Jinja2~=3.1.2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 132.7 MB/s eta 0:00:01
# Requirement already satisfied: click<9 in /opt/app-root/lib/python3.8/site-packages (from dbt-core) (8.0.1)
# Collecting agate~=1.7.0
#   Downloading agate-1.7.1-py2.py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 129.3 MB/s eta 0:00:01
# Collecting hologram~=0.0.16
#   Downloading hologram-0.0.16-py3-none-any.whl (11 kB)
# Requirement already satisfied: networkx<4,>=2.3 in /opt/app-root/lib/python3.8/site-packages (from dbt-core) (2.5.1)
# Requirement already satisfied: colorama<0.5,>=0.3.9 in /opt/app-root/lib/python3.8/site-packages (from dbt-core) (0.4.4)
# Collecting dbt-semantic-interfaces~=0.2.0
#   Downloading dbt_semantic_interfaces-0.2.0-py3-none-any.whl (99 kB)
#      |████████████████████████████████| 99 kB 126.2 MB/s eta 0:00:01
# Collecting mashumaro[msgpack]~=3.8.1
#   Downloading mashumaro-3.8.1-py3-none-any.whl (74 kB)
#      |████████████████████████████████| 74 kB 104.7 MB/s eta 0:00:01
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.8/site-packages (from dbt-core) (2.10)
# Collecting isodate<0.7,>=0.6
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 41.8 MB/s  eta 0:00:01
# Collecting dbt-extractor~=0.4.1
#   Downloading dbt_extractor-0.4.1-cp36-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 127.1 MB/s eta 0:00:01
# Collecting pathspec<0.12,>=0.9
#   Downloading pathspec-0.11.2-py3-none-any.whl (29 kB)
# Requirement already satisfied: requests<3.0.0 in /opt/app-root/lib/python3.8/site-packages (from dbt-core) (2.31.0)
# Requirement already satisfied: urllib3~=1.0 in /opt/app-root/lib/python3.8/site-packages (from dbt-core) (1.26.6)
# Collecting sqlparse<0.5,>=0.2.3
#   Downloading sqlparse-0.4.4-py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 17.3 MB/s  eta 0:00:01
# Collecting packaging>20.9
#   Downloading packaging-23.1-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 106.4 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2015.7 in /opt/app-root/lib/python3.8/site-packages (from dbt-core) (2021.1)
# Collecting pyyaml>=6.0
#   Downloading PyYAML-6.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (736 kB)
#      |████████████████████████████████| 736 kB 120.6 MB/s eta 0:00:01
# Collecting python-slugify>=1.2.1
#   Downloading python_slugify-8.0.1-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: Babel>=2.0 in /opt/app-root/lib/python3.8/site-packages (from agate~=1.7.0->dbt-core) (2.9.1)
# Collecting parsedatetime!=2.5,>=2.1
#   Downloading parsedatetime-2.6-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 59.4 MB/s  eta 0:00:01
# Collecting pytimeparse>=1.1.5
#   Downloading pytimeparse-1.1.8-py2.py3-none-any.whl (10.0 kB)
# Collecting leather>=0.3.2
#   Downloading leather-0.3.4-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: pycparser in /opt/app-root/lib/python3.8/site-packages (from cffi<2.0.0,>=1.9->dbt-core) (2.20)
# Collecting typing-extensions>=3.7.4
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting more-itertools~=8.0
#   Downloading more_itertools-8.14.0-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 61.2 MB/s  eta 0:00:01
# Requirement already satisfied: python-dateutil~=2.0 in /opt/app-root/lib/python3.8/site-packages (from dbt-semantic-interfaces~=0.2.0->dbt-core) (2.8.2)
# Requirement already satisfied: jsonschema~=3.0 in /opt/app-root/lib/python3.8/site-packages (from dbt-semantic-interfaces~=0.2.0->dbt-core) (3.2.0)
# Collecting importlib-metadata~=6.0
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Collecting pydantic~=1.10
#   Downloading pydantic-1.10.12-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 117.8 MB/s eta 0:00:01
# Requirement already satisfied: zipp>=0.5 in /opt/app-root/lib/python3.8/site-packages (from importlib-metadata~=6.0->dbt-semantic-interfaces~=0.2.0->dbt-core) (3.4.1)
# Requirement already satisfied: six in /opt/app-root/lib/python3.8/site-packages (from isodate<0.7,>=0.6->dbt-core) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/app-root/lib/python3.8/site-packages (from Jinja2~=3.1.2->dbt-core) (2.0.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/app-root/lib/python3.8/site-packages (from jsonschema~=3.0->dbt-semantic-interfaces~=0.2.0->dbt-core) (0.17.3)
# Requirement already satisfied: setuptools in /opt/app-root/lib/python3.8/site-packages (from jsonschema~=3.0->dbt-semantic-interfaces~=0.2.0->dbt-core) (57.0.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/app-root/lib/python3.8/site-packages (from jsonschema~=3.0->dbt-semantic-interfaces~=0.2.0->dbt-core) (21.2.0)
# Requirement already satisfied: msgpack>=0.5.6 in /opt/app-root/lib/python3.8/site-packages (from mashumaro[msgpack]~=3.8.1->dbt-core) (1.0.2)
# Requirement already satisfied: decorator<5,>=4.3 in /opt/app-root/lib/python3.8/site-packages (from networkx<4,>=2.3->dbt-core) (4.4.2)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 118.6 MB/s eta 0:00:01
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/app-root/lib/python3.8/site-packages (from requests<3.0.0->dbt-core) (3.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.8/site-packages (from requests<3.0.0->dbt-core) (2021.5.30)
# Requirement already satisfied: trino~=0.326 in /opt/app-root/lib/python3.8/site-packages (from dbt-trino) (0.326.0)
# Requirement already satisfied: tzlocal in /opt/app-root/lib/python3.8/site-packages (from trino~=0.326->dbt-trino) (2.1)
# Requirement already satisfied: backports.zoneinfo in /opt/app-root/lib/python3.8/site-packages (from trino~=0.326->dbt-trino) (0.2.1)
# Building wheels for collected packages: logbook, minimal-snowplow-tracker
#   Building wheel for logbook (setup.py) ... done
#   Created wheel for logbook: filename=Logbook-1.5.3-cp38-cp38-linux_x86_64.whl size=66394 sha256=6fd2746aed7ffa1a09b80dfbb0b20f3bf5aef8f7cbd0d95470bfb22be4e6ffa7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1c2pkjfm/wheels/25/9a/c0/03bf368ac5f673e9c0bde58837146b004424b25555ca3aedfb
#   Building wheel for minimal-snowplow-tracker (setup.py) ... done
#   Created wheel for minimal-snowplow-tracker: filename=minimal_snowplow_tracker-0.0.2-py3-none-any.whl size=17816 sha256=b80d99ce6fb5e7f744537840a14c137d4030ddc005887a3c6d5cec0030781a08
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1c2pkjfm/wheels/d4/04/77/72a8c17c9c19691be497bb4e192bd760aff6d47fa959d184e8
# Successfully built logbook minimal-snowplow-tracker
# Installing collected packages: typing-extensions, text-unidecode, pyyaml, pytimeparse, python-slugify, pydantic, parsedatetime, more-itertools, mashumaro, leather, Jinja2, isodate, importlib-metadata, sqlparse, protobuf, pathspec, packaging, minimal-snowplow-tracker, logbook, hologram, dbt-semantic-interfaces, dbt-extractor, agate, dbt-core, dbt-trino
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.0
#     Uninstalling typing-extensions-3.10.0.0:
#       Successfully uninstalled typing-extensions-3.10.0.0
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 5.4.1
#     Uninstalling PyYAML-5.4.1:
#       Successfully uninstalled PyYAML-5.4.1
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.6.0
#     Uninstalling importlib-metadata-4.6.0:
#       Successfully uninstalled importlib-metadata-4.6.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: pathspec
#     Found existing installation: pathspec 0.8.1
#     Uninstalling pathspec-0.8.1:
#       Successfully uninstalled pathspec-0.8.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.9
#     Uninstalling packaging-20.9:
#       Successfully uninstalled packaging-20.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thoth-python 0.16.1 requires beautifulsoup4==4.6.3, but you have beautifulsoup4 4.9.3 which is incompatible.
# kfp-pipeline-spec 0.1.8 requires protobuf<4,>=3.13.0, but you have protobuf 4.24.3 which is incompatible.
# elyra-server 2.2.4 requires jinja2<3.0,>=2.11, but you have jinja2 3.1.2 which is incompatible.
# elyra-server 2.2.4 requires pyyaml<6.0,>=5.3.1, but you have pyyaml 6.0.1 which is incompatible.
# Successfully installed Jinja2-3.1.2 agate-1.7.1 dbt-core-1.6.2 dbt-extractor-0.4.1 dbt-semantic-interfaces-0.2.0 dbt-trino-1.6.1 hologram-0.0.16 importlib-metadata-6.8.0 isodate-0.6.1 leather-0.3.4 logbook-1.5.3 mashumaro-3.8.1 minimal-snowplow-tracker-0.0.2 more-itertools-8.14.0 packaging-23.1 parsedatetime-2.6 pathspec-0.11.2 protobuf-4.24.3 pydantic-1.10.12 python-slugify-8.0.1 pytimeparse-1.1.8 pyyaml-6.0.1 sqlparse-0.4.4 text-unidecode-1.3 typing-extensions-4.7.1
# WARNING: You are using pip version 21.1.3; however, version 23.2.1 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
