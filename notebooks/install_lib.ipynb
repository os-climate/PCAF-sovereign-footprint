# %%
# 'capture' magic prevents long outputs from spamming your notebook
#%%capture pipoutput

# For loading predefined environment variables from files
# Typically used to load sensitive access credentials
# %pip install python-dotenv

# Standard python package for interacting with S3 buckets
# %pip install boto3
# Interacting with Trino and using Trino with sqlalchemy
# %pip install trino sqlalchemy sqlalchemy-trino

# Pandas and parquet file i/o
# %pip install pandas pyarrow fastparquet

# OS-Climate utilities to make data ingest easier
# %pip install osc-ingest-tools
# %pip install ipython --upgrade
# %pip install country_converter --upgrade
# %pip install pint-pandas
# %pip install openscm-units
# %pip install Pint==0.19.2
# %pip install jedi
# %pip install pycountry
# %pip install openpyxl
# %pip install xlwt
# %pip install dbt-core dbt-trino
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-0.21.0-py3-none-any.whl (18 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-0.21.0
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting boto3
#   Downloading boto3-1.26.18-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 84.8 MB/s eta 0:00:00
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 153.9 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting botocore<1.30.0,>=1.29.18
#   Downloading botocore-1.29.18-py3-none-any.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 147.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/app-root/lib/python3.8/site-packages (from botocore<1.30.0,>=1.29.18->boto3) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/app-root/lib/python3.8/site-packages (from botocore<1.30.0,>=1.29.18->boto3) (1.26.10)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.30.0,>=1.29.18->boto3) (1.16.0)
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.26.18 botocore-1.29.18 jmespath-1.0.1 s3transfer-0.6.0
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting trino
#   Downloading trino-0.319.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: sqlalchemy in /opt/app-root/lib/python3.8/site-packages (1.4.32)
# Collecting sqlalchemy-trino
#   Downloading sqlalchemy_trino-0.5.0-py3-none-any.whl (6.8 kB)
# Requirement already satisfied: requests in /opt/app-root/lib/python3.8/site-packages (from trino) (2.28.1)
# Requirement already satisfied: pytz in /opt/app-root/lib/python3.8/site-packages (from trino) (2022.1)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/app-root/lib/python3.8/site-packages (from sqlalchemy) (1.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.8/site-packages (from requests->trino) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.8/site-packages (from requests->trino) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/app-root/lib/python3.8/site-packages (from requests->trino) (1.26.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/app-root/lib/python3.8/site-packages (from requests->trino) (2.1.0)
# Installing collected packages: trino, sqlalchemy-trino
# Successfully installed sqlalchemy-trino-0.5.0 trino-0.319.0
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting pandas
#   Downloading pandas-1.5.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 151.7 MB/s eta 0:00:00a 0:00:01
# Collecting pyarrow
#   Downloading pyarrow-10.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.0/36.0 MB 164.2 MB/s eta 0:00:00a 0:00:01
# Collecting fastparquet
#   Downloading fastparquet-2022.11.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 196.1 MB/s eta 0:00:00
# Collecting numpy>=1.20.3
#   Downloading numpy-1.23.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 170.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.8/site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/app-root/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: packaging in /opt/app-root/lib/python3.8/site-packages (from fastparquet) (21.3)
# Collecting fsspec
#   Downloading fsspec-2022.11.0-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.5/139.5 kB 182.4 MB/s eta 0:00:00
# Collecting cramjam>=2.3
#   Downloading cramjam-2.6.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 153.5 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/app-root/lib/python3.8/site-packages (from packaging->fastparquet) (3.0.9)
# Installing collected packages: numpy, fsspec, cramjam, pyarrow, pandas, fastparquet
# Successfully installed cramjam-2.6.2 fastparquet-2022.11.0 fsspec-2022.11.0 numpy-1.23.5 pandas-1.5.2 pyarrow-10.0.1
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting osc-ingest-tools
#   Downloading osc_ingest_tools-0.4.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: pandas in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (1.5.2)
# Requirement already satisfied: trino[sqlalchemy] in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (0.319.0)
# Requirement already satisfied: python-dotenv in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (0.21.0)
# Requirement already satisfied: boto3 in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (1.26.18)
# Requirement already satisfied: sqlalchemy in /opt/app-root/lib/python3.8/site-packages (from osc-ingest-tools) (1.4.32)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/app-root/lib/python3.8/site-packages (from boto3->osc-ingest-tools) (1.0.1)
# Requirement already satisfied: botocore<1.30.0,>=1.29.18 in /opt/app-root/lib/python3.8/site-packages (from boto3->osc-ingest-tools) (1.29.18)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /opt/app-root/lib/python3.8/site-packages (from boto3->osc-ingest-tools) (0.6.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/app-root/lib/python3.8/site-packages (from pandas->osc-ingest-tools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.8/site-packages (from pandas->osc-ingest-tools) (2022.1)
# Requirement already satisfied: numpy>=1.20.3 in /opt/app-root/lib/python3.8/site-packages (from pandas->osc-ingest-tools) (1.23.5)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/app-root/lib/python3.8/site-packages (from sqlalchemy->osc-ingest-tools) (1.1.2)
# Requirement already satisfied: requests in /opt/app-root/lib/python3.8/site-packages (from trino[sqlalchemy]->osc-ingest-tools) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/app-root/lib/python3.8/site-packages (from botocore<1.30.0,>=1.29.18->boto3->osc-ingest-tools) (1.26.10)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->osc-ingest-tools) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/app-root/lib/python3.8/site-packages (from requests->trino[sqlalchemy]->osc-ingest-tools) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.8/site-packages (from requests->trino[sqlalchemy]->osc-ingest-tools) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.8/site-packages (from requests->trino[sqlalchemy]->osc-ingest-tools) (3.3)
# Installing collected packages: osc-ingest-tools
# Successfully installed osc-ingest-tools-0.4.2
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipython in /opt/app-root/lib/python3.8/site-packages (8.4.0)
# Collecting ipython
#   Downloading ipython-8.7.0-py3-none-any.whl (761 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 761.7/761.7 kB 126.4 MB/s eta 0:00:00
# Requirement already satisfied: stack-data in /opt/app-root/lib/python3.8/site-packages (from ipython) (0.3.0)
# Requirement already satisfied: matplotlib-inline in /opt/app-root/lib/python3.8/site-packages (from ipython) (0.1.3)
# Requirement already satisfied: pickleshare in /opt/app-root/lib/python3.8/site-packages (from ipython) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in /opt/app-root/lib/python3.8/site-packages (from ipython) (2.12.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in /opt/app-root/lib/python3.8/site-packages (from ipython) (3.0.30)
# Requirement already satisfied: backcall in /opt/app-root/lib/python3.8/site-packages (from ipython) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /opt/app-root/lib/python3.8/site-packages (from ipython) (5.3.0)
# Requirement already satisfied: pexpect>4.3 in /opt/app-root/lib/python3.8/site-packages (from ipython) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /opt/app-root/lib/python3.8/site-packages (from ipython) (0.18.1)
# Requirement already satisfied: decorator in /opt/app-root/lib/python3.8/site-packages (from ipython) (5.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/app-root/lib/python3.8/site-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/app-root/lib/python3.8/site-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/app-root/lib/python3.8/site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython) (0.2.5)
# Requirement already satisfied: asttokens in /opt/app-root/lib/python3.8/site-packages (from stack-data->ipython) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/app-root/lib/python3.8/site-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: executing in /opt/app-root/lib/python3.8/site-packages (from stack-data->ipython) (0.8.3)
# Requirement already satisfied: six in /opt/app-root/lib/python3.8/site-packages (from asttokens->stack-data->ipython) (1.16.0)
# Installing collected packages: ipython
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.4.0
#     Uninstalling ipython-8.4.0:
#       Successfully uninstalled ipython-8.4.0
# Successfully installed ipython-8.7.0
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting country_converter
#   Downloading country_converter-0.8.0.tar.gz (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 82.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.0 in /opt/app-root/lib/python3.8/site-packages (from country_converter) (1.5.2)
# Requirement already satisfied: numpy>=1.20.3 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.0->country_converter) (1.23.5)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.0->country_converter) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.0->country_converter) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=1.0->country_converter) (1.16.0)
# Building wheels for collected packages: country_converter
#   Building wheel for country_converter (setup.py) ... done
#   Created wheel for country_converter: filename=country_converter-0.8.0-py3-none-any.whl size=55641 sha256=885249bb0dc99031053d6f30a24bc86a8f4eac10eda319f7e888f2f5fbc1b577
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8nh6n7f3/wheels/c2/5a/f6/7187fa51e18f2ed105833a7f5c44a2475ace0c96e19118e608
# Successfully built country_converter
# Installing collected packages: country_converter
# Successfully installed country_converter-0.8.0
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting pint-pandas
#   Downloading Pint_Pandas-0.3-py2.py3-none-any.whl (23 kB)
# Collecting pint>=0.20.1
#   Downloading Pint-0.20.1-py3-none-any.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.5/269.5 kB 77.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.5 in /opt/app-root/lib/python3.8/site-packages (from pint-pandas) (1.5.2)
# Requirement already satisfied: numpy>=1.20.3 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.5->pint-pandas) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.5->pint-pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.5->pint-pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=1.5->pint-pandas) (1.16.0)
# Installing collected packages: pint, pint-pandas
# Successfully installed pint-0.20.1 pint-pandas-0.3
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting openscm-units
#   Downloading openscm_units-0.5.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: pint in /opt/app-root/lib/python3.8/site-packages (from openscm-units) (0.20.1)
# Requirement already satisfied: pandas in /opt/app-root/lib/python3.8/site-packages (from openscm-units) (1.5.2)
# Collecting globalwarmingpotentials
#   Downloading globalwarmingpotentials-0.9.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.8/site-packages (from pandas->openscm-units) (2022.1)
# Requirement already satisfied: numpy>=1.20.3 in /opt/app-root/lib/python3.8/site-packages (from pandas->openscm-units) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/app-root/lib/python3.8/site-packages (from pandas->openscm-units) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->openscm-units) (1.16.0)
# Installing collected packages: globalwarmingpotentials, openscm-units
# Successfully installed globalwarmingpotentials-0.9.3 openscm-units-0.5.0
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting Pint==0.19.2
#   Downloading Pint-0.19.2.tar.gz (292 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.0/292.0 kB 78.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: Pint
#   Building wheel for Pint (pyproject.toml) ... done
#   Created wheel for Pint: filename=Pint-0.19.2-py3-none-any.whl size=231001 sha256=44678b4f474caca8d34d467be84a5e1f7f035c9fbe0ecacd466ef2377255d62e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xkiib05d/wheels/98/1d/e0/a44541f5302ac50028a3be0db9417c18092c61f25009d62145
# Successfully built Pint
# Installing collected packages: Pint
#   Attempting uninstall: Pint
#     Found existing installation: Pint 0.20.1
#     Uninstalling Pint-0.20.1:
#       Successfully uninstalled Pint-0.20.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pint-pandas 0.3 requires pint>=0.20.1, but you have pint 0.19.2 which is incompatible.
# Successfully installed Pint-0.19.2
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: jedi in /opt/app-root/lib/python3.8/site-packages (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/app-root/lib/python3.8/site-packages (from jedi) (0.8.3)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting pycountry
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 107.3 MB/s eta 0:00:00 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools in /opt/app-root/lib/python3.8/site-packages (from pycountry) (63.2.0)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (pyproject.toml) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681832 sha256=914c8267fa50ba0ce8c4758b4825765f1de61f832d6db80225738c9b95113d9f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jxo_h5db/wheels/e2/aa/0f/c224e473b464387170b83ca7c66947b4a7e33e8d903a679748
# Successfully built pycountry
# Installing collected packages: pycountry
# Successfully installed pycountry-22.3.5
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting openpyxl
#   Downloading openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 kB 8.4 MB/s eta 0:00:00
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.10
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting xlwt
#   Downloading xlwt-1.3.0-py2.py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 58.5 MB/s eta 0:00:00
# Installing collected packages: xlwt
# Successfully installed xlwt-1.3.0
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting dbt-core
#   Downloading dbt_core-1.3.1-py3-none-any.whl (903 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 903.5/903.5 kB 18.3 MB/s eta 0:00:00a 0:00:01
# Collecting dbt-trino
#   Downloading dbt_trino-1.3.1-py3-none-any.whl (35 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in /opt/app-root/lib/python3.8/site-packages (from dbt-core) (4.3.0)
# Collecting minimal-snowplow-tracker==0.0.2
#   Downloading minimal-snowplow-tracker-0.0.2.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.8/site-packages (from dbt-core) (3.3)
# Requirement already satisfied: click<9,>=7.0 in /opt/app-root/lib/python3.8/site-packages (from dbt-core) (8.1.3)
# Collecting isodate<0.7,>=0.6
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 129.7 MB/s eta 0:00:00
# Collecting mashumaro[msgpack]==3.0.4
#   Downloading mashumaro-3.0.4-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 107.8 MB/s eta 0:00:00
# Requirement already satisfied: colorama<0.4.6,>=0.3.9 in /opt/app-root/lib/python3.8/site-packages (from dbt-core) (0.4.5)
# Requirement already satisfied: networkx<3,>=2.3 in /opt/app-root/lib/python3.8/site-packages (from dbt-core) (2.8.5)
# Collecting dbt-extractor~=0.4.1
#   Downloading dbt_extractor-0.4.1-cp36-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 122.1 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2==3.1.2 in /opt/app-root/lib/python3.8/site-packages (from dbt-core) (3.1.2)
# Collecting agate<1.6.4,>=1.6
#   Downloading agate-1.6.3-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.5/100.5 kB 166.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging<22.0,>=20.9 in /opt/app-root/lib/python3.8/site-packages (from dbt-core) (21.3)
# Requirement already satisfied: pathspec~=0.9.0 in /opt/app-root/lib/python3.8/site-packages (from dbt-core) (0.9.0)
# Collecting hologram<=0.0.15,>=0.0.14
#   Downloading hologram-0.0.15-py3-none-any.whl (11 kB)
# Collecting sqlparse<0.5,>=0.2.3
#   Downloading sqlparse-0.4.3-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 121.4 MB/s eta 0:00:00
# Collecting werkzeug<3,>=1
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.7/232.7 kB 184.5 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0 in /opt/app-root/lib/python3.8/site-packages (from dbt-core) (2.28.1)
# Collecting logbook<1.6,>=1.5
#   Downloading Logbook-1.5.3.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.8/85.8 kB 151.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyyaml>=6.0
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 701.2/701.2 kB 203.2 MB/s eta 0:00:00
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /opt/app-root/lib/python3.8/site-packages (from dbt-core) (1.15.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/app-root/lib/python3.8/site-packages (from Jinja2==3.1.2->dbt-core) (2.1.1)
# Collecting msgpack>=0.5.6
#   Downloading msgpack-1.0.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.5/322.5 kB 184.4 MB/s eta 0:00:00
# Requirement already satisfied: six<2.0,>=1.9.0 in /opt/app-root/lib/python3.8/site-packages (from minimal-snowplow-tracker==0.0.2->dbt-core) (1.16.0)
# Collecting trino==0.318.0
#   Downloading trino-0.318.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 99.6 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /opt/app-root/lib/python3.8/site-packages (from trino==0.318.0->dbt-trino) (2022.1)
# Collecting python-slugify>=1.2.1
#   Downloading python_slugify-7.0.0-py2.py3-none-any.whl (9.4 kB)
# Collecting parsedatetime!=2.5,!=2.6,>=2.1
#   Downloading parsedatetime-2.4.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 154.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting leather>=0.3.2
#   Downloading leather-0.3.4-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: Babel>=2.0 in /opt/app-root/lib/python3.8/site-packages (from agate<1.6.4,>=1.6->dbt-core) (2.10.3)
# Collecting pytimeparse>=1.1.5
#   Downloading pytimeparse-1.1.8-py2.py3-none-any.whl (10.0 kB)
# Requirement already satisfied: pycparser in /opt/app-root/lib/python3.8/site-packages (from cffi<2.0.0,>=1.9->dbt-core) (2.21)
# Requirement already satisfied: jsonschema<4.0,>=3.0 in /opt/app-root/lib/python3.8/site-packages (from hologram<=0.0.15,>=0.0.14->dbt-core) (3.2.0)
# Requirement already satisfied: python-dateutil<2.9,>=2.8 in /opt/app-root/lib/python3.8/site-packages (from hologram<=0.0.15,>=0.0.14->dbt-core) (2.8.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/app-root/lib/python3.8/site-packages (from packaging<22.0,>=20.9->dbt-core) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.8/site-packages (from requests<3.0.0->dbt-core) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/app-root/lib/python3.8/site-packages (from requests<3.0.0->dbt-core) (1.26.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/app-root/lib/python3.8/site-packages (from requests<3.0.0->dbt-core) (2.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/app-root/lib/python3.8/site-packages (from jsonschema<4.0,>=3.0->hologram<=0.0.15,>=0.0.14->dbt-core) (0.18.1)
# Requirement already satisfied: setuptools in /opt/app-root/lib/python3.8/site-packages (from jsonschema<4.0,>=3.0->hologram<=0.0.15,>=0.0.14->dbt-core) (63.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/app-root/lib/python3.8/site-packages (from jsonschema<4.0,>=3.0->hologram<=0.0.15,>=0.0.14->dbt-core) (21.4.0)
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.2/829.2 kB 180.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 153.2 MB/s eta 0:00:00
# Building wheels for collected packages: minimal-snowplow-tracker, logbook, parsedatetime, future
#   Building wheel for minimal-snowplow-tracker (setup.py) ... done
#   Created wheel for minimal-snowplow-tracker: filename=minimal_snowplow_tracker-0.0.2-py3-none-any.whl size=17802 sha256=a13971f3c626e888a10b1ae03362d5ec9408bb1691534376832d2c7c90dd6910
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ndh8xdjd/wheels/d4/04/77/72a8c17c9c19691be497bb4e192bd760aff6d47fa959d184e8
#   Building wheel for logbook (setup.py) ... done
#   Created wheel for logbook: filename=Logbook-1.5.3-cp38-cp38-linux_x86_64.whl size=65611 sha256=2aad2acef648a1c020629f182dc2e2b3b04e70182c19cde309b1bc510dc2f646
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ndh8xdjd/wheels/25/9a/c0/03bf368ac5f673e9c0bde58837146b004424b25555ca3aedfb
#   Building wheel for parsedatetime (setup.py) ... done
#   Created wheel for parsedatetime: filename=parsedatetime-2.4-py3-none-any.whl size=42773 sha256=7f41e844433d8368a827c46182086b156b8de1b2872ac3f81ba2dcdc360d0a9e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ndh8xdjd/wheels/e5/2b/42/2b5388ce43276783c42176a76229c21f74e4433a8e2a0daae6
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491058 sha256=9601ac3bd64893da41abbe070b3c0c96321d486039dc04eedb32036b870b49b5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ndh8xdjd/wheels/8e/70/28/3d6ccd6e315f65f245da085482a2e1c7d14b90b30f239e2cf4
# Successfully built minimal-snowplow-tracker logbook parsedatetime future
# Installing collected packages: text-unidecode, pytimeparse, msgpack, logbook, werkzeug, sqlparse, pyyaml, python-slugify, mashumaro, leather, isodate, future, dbt-extractor, trino, parsedatetime, minimal-snowplow-tracker, hologram, agate, dbt-core, dbt-trino
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 5.4.1
#     Uninstalling PyYAML-5.4.1:
#       Successfully uninstalled PyYAML-5.4.1
#   Attempting uninstall: trino
#     Found existing installation: trino 0.319.0
#     Uninstalling trino-0.319.0:
#       Successfully uninstalled trino-0.319.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thoth-common 0.36.0 requires kubernetes~=11.0.0, but you have kubernetes 18.20.0 which is incompatible.
# kfp 1.8.13 requires PyYAML<6,>=5.3, but you have pyyaml 6.0 which is incompatible.
# elyra 3.10.1 requires pyyaml<6.0,>=5.3.1, but you have pyyaml 6.0 which is incompatible.
# Successfully installed agate-1.6.3 dbt-core-1.3.1 dbt-extractor-0.4.1 dbt-trino-1.3.1 future-0.18.2 hologram-0.0.15 isodate-0.6.1 leather-0.3.4 logbook-1.5.3 mashumaro-3.0.4 minimal-snowplow-tracker-0.0.2 msgpack-1.0.4 parsedatetime-2.4 python-slugify-7.0.0 pytimeparse-1.1.8 pyyaml-6.0 sqlparse-0.4.3 text-unidecode-1.3 trino-0.318.0 werkzeug-2.2.2
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
