# %% [markdown]
# <font size="5">OECD CO2 emissions into Trino pipeline</font>

# %% [markdown]
# https://stats.oecd.org/Index.aspx?DataSetCode=IO_GHG_2019#

# %%
from dotenv import dotenv_values, load_dotenv
import osc_ingest_trino as osc
import os
import pathlib
dotenv_dir = os.environ.get('CREDENTIAL_DOTENV_DIR', os.environ.get('PWD', '/opt/app-root/src'))
dotenv_path = pathlib.Path(dotenv_dir) / 'credentials.env'
if os.path.exists(dotenv_path):
    load_dotenv(dotenv_path=dotenv_path,override=True)

# %%
# use a catalog that is configured for iceberg
ingest_catalog = 'osc_datacommons_dev'
ingest_schema = 'pcaf_sovereign_footprint'
ingest_table = 'sf_oecd_exgr_dco2'

# %%
import trino
from sqlalchemy.engine import create_engine

env_var_prefix = 'TRINO'

sqlstring = 'trino://{user}@{host}:{port}/'.format(
    user = os.environ[f'{env_var_prefix}_USER'],
    host = os.environ[f'{env_var_prefix}_HOST'],
    port = os.environ[f'{env_var_prefix}_PORT']
)
sqlargs = {
    'auth': trino.auth.JWTAuthentication(os.environ[f'{env_var_prefix}_PASSWD']),
    'http_scheme': 'https',
    'catalog': 'osc_datacommons_dev'
}
engine = create_engine(sqlstring, connect_args = sqlargs)
connection = engine.connect()

trino_bucket = osc.attach_s3_bucket("S3_DEV")

# %%
import boto3

s3_source = boto3.resource(
    service_name="s3",
    endpoint_url=os.environ['S3_LANDING_ENDPOINT'],
    aws_access_key_id=os.environ['S3_LANDING_ACCESS_KEY'],
    aws_secret_access_key=os.environ['S3_LANDING_SECRET_KEY'],
)
source_bucket = s3_source.Bucket(os.environ['S3_LANDING_BUCKET'])

# %% [markdown]
# Open a Trino connection using JWT for authentication

# %%
# make sure schema exists, or table creation below will fail in weird ways
sql = f"""
create schema if not exists {ingest_catalog}.{ingest_schema}
"""
qres = engine.execute(sql)
print(qres.fetchall())
# Out:
# [(True,)]

# %%
# Show available schemas to ensure trino connection is set correctly
schema_read = engine.execute(f'show schemas in {ingest_catalog}')
for row in schema_read.fetchall():
    print(row)
# Out:
# ('default',)
# ('demo_dv',)
# ('iceberg_demo',)
# ('information_schema',)
# ('ingest',)
# ('mdt_sandbox',)
# ('pcaf_sovereign_footprint',)
# ('sandbox',)

# %% [markdown]
# #Load CO2 emissions file (updated from https://stats.oecd.org/Index.aspx)

# %%
import pandas as pd
import csv
import ParseXLS as parser


oecd_file = s3_source.Object(os.environ['S3_LANDING_BUCKET'],'PCAF-sovereign-footprint/OECD/EXGR_DCO2.csv')
oecd_file.download_file(f'/tmp/EXGR_DCO2.csv')
df =pd.read_csv(f'/tmp/EXGR_DCO2.csv')
df= df[['Indicator','COU','Country','PAR','IND','Industry','TIME','Value']]
df=df.convert_dtypes()
dict = {'Indicator': 'attribute',
        'COU': 'country_iso_code',
        'Country': 'country_name',
        'PAR': 'partner_iso_code',
        'IND': 'industry_code',
        'Industry' : 'industry_name',
        'TIME'   : 'validity_date',
        'Value' : 'value' }

df.rename(columns=dict,
          inplace=True)
df['value_units'] = 'Mt CO2'
df
# Out:
#                                                 attribute country_iso_code  \
# 0       Domestic CO2 emissions embodied in gross exports              OECD
# 1       Domestic CO2 emissions embodied in gross exports              OECD
# 2       Domestic CO2 emissions embodied in gross exports              OECD
# 3       Domestic CO2 emissions embodied in gross exports              OECD
# 4       Domestic CO2 emissions embodied in gross exports              OECD
# ...                                                   ...              ...
# 334651  Domestic CO2 emissions embodied in gross exports              ZOTH
# 334652  Domestic CO2 emissions embodied in gross exports              ZOTH
# 334653  Domestic CO2 emissions embodied in gross exports              ZOTH
# 334654  Domestic CO2 emissions embodied in gross exports              ZOTH
# 334655  Domestic CO2 emissions embodied in gross exports              ZOTH
#
#                  country_name partner_iso_code industry_code  \
# 0       OECD member countries              WLD        DTOTAL
# 1       OECD member countries              WLD        DTOTAL
# 2       OECD member countries              WLD        DTOTAL
# 3       OECD member countries              WLD        DTOTAL
# 4       OECD member countries              WLD        DTOTAL
# ...                       ...              ...           ...
# 334651         Other regions               MMR           D35
# 334652         Other regions               MMR           D35
# 334653         Other regions               MMR           D35
# 334654         Other regions               MMR           D35
# 334655         Other regions               MMR           D35
#
#                                             industry_name  validity_date  \
# 0                                                   TOTAL           1995
# 1                                                   TOTAL           1996
# 2                                                   TOTAL           1997
# 3                                                   TOTAL           1998
# 4                                                   TOTAL           1999
# ...                                                   ...            ...
# 334651  Electricity, gas, steam and air conditioning s...           2014
# 334652  Electricity, gas, steam and air conditioning s...           2015
# 334653  Electricity, gas, steam and air conditioning s...           2016
# 334654  Electricity, gas, steam and air conditioning s...           2017
# 334655  Electricity, gas, steam and air conditioning s...           2018
#
#           value value_units
# 0       530.637      Mt CO2
# 1       580.962      Mt CO2
# 2       638.161      Mt CO2
# 3       605.956      Mt CO2
# 4       576.039      Mt CO2
# ...         ...         ...
# 334651    0.027      Mt CO2
# 334652    0.073      Mt CO2
# 334653    0.051      Mt CO2
# 334654    0.214      Mt CO2
# 334655    0.258      Mt CO2
#
# [334656 rows x 9 columns]

# %%
import osc_ingest_trino as osc
df = df.convert_dtypes()
columnschema = osc.create_table_schema_pairs(df) 

sql = f"""
drop table if exists {ingest_catalog}.{ingest_schema}.{ingest_table}
"""
print(sql)
qres = engine.execute(sql)
print(qres.fetchall())
# Out:
# drop table if exists osc_datacommons_dev.pcaf_sovereign_footprint.sf_oecd_exgr_dco2
#
# [(True,)]

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334656 entries, 0 to 334655
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   attribute         334656 non-null  string
#  1   country_iso_code  334656 non-null  string
#  2   country_name      334656 non-null  string
#  3   partner_iso_code  334656 non-null  string
#  4   industry_code     334656 non-null  string
#  5   industry_name     334656 non-null  string
#  6   validity_date     334656 non-null  Int64
#  7   value             334656 non-null  Float64
#  8   value_units       334656 non-null  string
# dtypes: Float64(1), Int64(1), string(7)
# memory usage: 23.6 MB

# %%
df.to_sql(ingest_table,
           con=engine,
           schema=ingest_schema,
           if_exists='append',
           index=False,
           method=osc.TrinoBatchInsert(batch_size = 5000, verbose = True))
# Out:
# constructed fully qualified table name as: "pcaf_sovereign_footprint.sf_oecd_exgr_dco2"
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'OECD', 'OECD member countries', 'WLD', 'DTOTAL', 'TOTAL', 1995, 530.637, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'OECD', 'OECD member countries', 'WLD', 'DTOTAL', 'TOTAL', 1996, 580.962, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'OECD', 'OECD member countries', 'WLD', 'DTOTAL', 'TOTAL', 1997, 638.161, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'AUS', 'Australia', 'NONOECD', 'DTOTAL', 'TOTAL', 2002, 32.168, 'Mt CO2')
# batch insert result: [(5000,)]
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'AUS', 'Australia', 'NONOECD', 'DTOTAL', 'TOTAL', 2003, 33.225, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'AUS', 'Australia', 'NONOECD', 'DTOTAL', 'TOTAL', 2004, 34.556, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'AUS', 'Australia', 'NONOECD', 'DTOTAL', 'TOTAL', 2005, 35.117, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'AUT', 'Austria', 'ZASI', 'DTOTAL', 'TOTAL', 2010, 1.555, 'Mt CO2')
# batch insert result: [(5000,)]
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'AUT', 'Austria', 'ZASI', 'DTOTAL', 'TOTAL', 2011, 1.55, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'AUT', 'Austria', 'ZASI', 'DTOTAL', 'TOTAL', 2012, 1.593, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'AUT', 'Austria', 'ZASI', 'DTOTAL', 'TOTAL', 2013, 1.642, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'BEL', 'Belgium', 'CHE', 'D35', 'Electricity, gas, steam and air conditioning supply', 2018, 0.003, 'Mt CO2')
# batch insert result: [(5000,)]
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'BEL', 'Belgium', 'TUR', 'D35', 'Electricity, gas, steam and air conditioning supply', 1995, 0.004, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'BEL', 'Belgium', 'TUR', 'D35', 'Electricity, gas, steam and air conditioning supply', 1996, 0.001, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'BEL', 'Belgium', 'TUR', 'D35', 'Electricity, gas, steam and air conditioning supply', 1997, 0.001, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'CAN', 'Canada', 'G20', 'D35', 'Electricity, gas, steam and air conditioning supply', 2002, 8.06, 'Mt CO2')
# batch insert result: [(5000,)]
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'CAN', 'Canada', 'G20', 'D35', 'Electricity, gas, steam and air conditioning supply', 2003, 8.099, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'CAN', 'Canada', 'G20', 'D35', 'Electricity, gas, steam and air conditioning supply', 2004, 8.273, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'CAN', 'Canada', 'G20', 'D35', 'Electricity, gas, steam and air conditioning supply', 2005, 11.183, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'COL', 'Colombia', 'SVN', 'DTOTAL', 'TOTAL', 2010, 0.004, 'Mt CO2')
# batch insert result: [(5000,)]
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'COL', 'Colombia', 'SVN', 'DTOTAL', 'TOTAL', 2011, 0.002, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'COL', 'Colombia', 'SVN', 'DTOTAL', 'TOTAL', 2012, 0.004, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'COL', 'Colombia', 'SVN', 'DTOTAL', 'TOTAL', 2013, 0.007, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'CRI', 'Costa Rica', 'TUN', 'DTOTAL', 'TOTAL', 2018, 0.0, 'Mt CO2')
# batch insert result: [(5000,)]
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'CRI', 'Costa Rica', 'VNM', 'DTOTAL', 'TOTAL', 1995, 0.002, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'CRI', 'Costa Rica', 'VNM', 'DTOTAL', 'TOTAL', 1996, 0.004, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'CRI', 'Costa Rica', 'VNM', 'DTOTAL', 'TOTAL', 1997, 0.003, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'CZE', 'Czech Republic', 'POL', 'D35', 'Electricity, gas, steam and air conditioning supply', 2002, 0.459, 'Mt CO2')
# batch insert result: [(5000,)]
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'CZE', 'Czech Republic', 'POL', 'D35', 'Electricity, gas, steam and air conditioning supply', 2003, 0.118, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'CZE', 'Czech Republic', 'POL', 'D35', 'Electricity, gas, steam and air conditioning supply', 2004, 0.249, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'CZE', 'Czech Republic', 'POL', 'D35', 'Electricity, gas, steam and air conditioning supply', 2005, 0.037, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'DNK', 'Denmark', 'ASEAN', 'D35', 'Electricity, gas, steam and air conditioning supply', 2010, 0.003, 'Mt CO2')
# batch insert result: [(5000,)]
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'DNK', 'Denmark', 'ASEAN', 'D35', 'Electricity, gas, steam and air conditioning supply', 2011, 0.016, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'DNK', 'Denmark', 'ASEAN', 'D35', 'Electricity, gas, steam and air conditioning supply', 2012, 0.017, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'DNK', 'Denmark', 'ASEAN', 'D35', 'Electricity, gas, steam and air conditioning supply', 2013, 0.006, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'FIN', 'Finland', 'MEX', 'DTOTAL', 'TOTAL', 2018, 0.095, 'Mt CO2')
# batch insert result: [(5000,)]
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'FIN', 'Finland', 'NLD', 'DTOTAL', 'TOTAL', 1995, 0.932, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'FIN', 'Finland', 'NLD', 'DTOTAL', 'TOTAL', 1996, 0.915, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'FIN', 'Finland', 'NLD', 'DTOTAL', 'TOTAL', 1997, 0.948, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'FRA', 'France', 'VNM', 'DTOTAL', 'TOTAL', 2002, 0.122, 'Mt CO2')
# batch insert result: [(5000,)]
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'FRA', 'France', 'VNM', 'DTOTAL', 'TOTAL', 2003, 0.165, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'FRA', 'France', 'VNM', 'DTOTAL', 'TOTAL', 2004, 0.192, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'FRA', 'France', 'VNM', 'DTOTAL', 'TOTAL', 2005, 0.116, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'DEU', 'Germany', 'LVA', 'D35', 'Electricity, gas, steam and air conditioning supply', 2010, 0.002, 'Mt CO2')
# batch insert result: [(5000,)]
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'DEU', 'Germany', 'LVA', 'D35', 'Electricity, gas, steam and air conditioning supply', 2011, 0.003, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'DEU', 'Germany', 'LVA', 'D35', 'Electricity, gas, steam and air conditioning supply', 2012, 0.002, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'DEU', 'Germany', 'LVA', 'D35', 'Electricity, gas, steam and air conditioning supply', 2013, 0.003, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'GRC', 'Greece', 'ZAF', 'D35', 'Electricity, gas, steam and air conditioning supply', 2018, 0.0, 'Mt CO2')
# batch insert result: [(5000,)]
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'GRC', 'Greece', 'TWN', 'D35', 'Electricity, gas, steam and air conditioning supply', 1995, 0.0, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'GRC', 'Greece', 'TWN', 'D35', 'Electricity, gas, steam and air conditioning supply', 1996, 0.0, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'GRC', 'Greece', 'TWN', 'D35', 'Electricity, gas, steam and air conditioning supply', 1997, 0.0, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'ISL', 'Iceland', 'ITA', 'DTOTAL', 'TOTAL', 2002, 0.019, 'Mt CO2')
# batch insert result: [(5000,)]
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'ISL', 'Iceland', 'ITA', 'DTOTAL', 'TOTAL', 2003, 0.005, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'ISL', 'Iceland', 'ITA', 'DTOTAL', 'TOTAL', 2004, 0.005, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'ISL', 'Iceland', 'ITA', 'DTOTAL', 'TOTAL', 2005, 0.008, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'IRL', 'Ireland', 'RUS', 'DTOTAL', 'TOTAL', 2010, 0.548, 'Mt CO2')
# batch insert result: [(5000,)]
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'IRL', 'Ireland', 'RUS', 'DTOTAL', 'TOTAL', 2011, 0.565, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'IRL', 'Ireland', 'RUS', 'DTOTAL', 'TOTAL', 2012, 0.58, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'IRL', 'Ireland', 'RUS', 'DTOTAL', 'TOTAL', 2013, 0.624, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'ISR', 'Israel', 'HUN', 'D35', 'Electricity, gas, steam and air conditioning supply', 2018, 0.0, 'Mt CO2')
# batch insert result: [(5000,)]
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'ISR', 'Israel', 'ISL', 'D35', 'Electricity, gas, steam and air conditioning supply', 1995, 0.0, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'ISR', 'Israel', 'ISL', 'D35', 'Electricity, gas, steam and air conditioning supply', 1996, 0.0, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'ISR', 'Israel', 'ISL', 'D35', 'Electricity, gas, steam and air conditioning supply', 1997, 0.0, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'ITA', 'Italy', 'PER', 'D35', 'Electricity, gas, steam and air conditioning supply', 2002, 0.001, 'Mt CO2')
# batch insert result: [(5000,)]
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'ITA', 'Italy', 'PER', 'D35', 'Electricity, gas, steam and air conditioning supply', 2003, 0.0, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'ITA', 'Italy', 'PER', 'D35', 'Electricity, gas, steam and air conditioning supply', 2004, 0.0, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'ITA', 'Italy', 'PER', 'D35', 'Electricity, gas, steam and air conditioning supply', 2005, 0.0, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'KOR', 'Korea', 'FRA', 'DTOTAL', 'TOTAL', 2010, 2.063, 'Mt CO2')
# batch insert result: [(5000,)]
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'KOR', 'Korea', 'FRA', 'DTOTAL', 'TOTAL', 2011, 2.271, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'KOR', 'Korea', 'FRA', 'DTOTAL', 'TOTAL', 2012, 1.678, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'KOR', 'Korea', 'FRA', 'DTOTAL', 'TOTAL', 2013, 2.161, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'LVA', 'Latvia', 'LAO', 'DTOTAL', 'TOTAL', 2018, 0.0, 'Mt CO2')
# batch insert result: [(5000,)]
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'LVA', 'Latvia', 'MYS', 'DTOTAL', 'TOTAL', 1995, 0.013, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'LVA', 'Latvia', 'MYS', 'DTOTAL', 'TOTAL', 1996, 0.036, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'LVA', 'Latvia', 'MYS', 'DTOTAL', 'TOTAL', 1997, 0.033, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'LTU', 'Lithuania', 'DNK', 'D35', 'Electricity, gas, steam and air conditioning supply', 2002, 0.003, 'Mt CO2')
# batch insert result: [(5000,)]
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'LTU', 'Lithuania', 'DNK', 'D35', 'Electricity, gas, steam and air conditioning supply', 2003, 0.001, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'LTU', 'Lithuania', 'DNK', 'D35', 'Electricity, gas, steam and air conditioning supply', 2004, 0.011, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'LTU', 'Lithuania', 'DNK', 'D35', 'Electricity, gas, steam and air conditioning supply', 2005, 0.001, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'LUX', 'Luxembourg', 'IND', 'D35', 'Electricity, gas, steam and air conditioning supply', 2010, 0.0, 'Mt CO2')
# batch insert result: [(5000,)]
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'LUX', 'Luxembourg', 'IND', 'D35', 'Electricity, gas, steam and air conditioning supply', 2011, 0.0, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'LUX', 'Luxembourg', 'IND', 'D35', 'Electricity, gas, steam and air conditioning supply', 2012, 0.0, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'LUX', 'Luxembourg', 'IND', 'D35', 'Electricity, gas, steam and air conditioning supply', 2013, 0.0, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'NLD', 'Netherlands', 'CHL', 'DTOTAL', 'TOTAL', 2018, 0.068, 'Mt CO2')
# batch insert result: [(5000,)]
# inserting 5000 records
#   ('Domestic CO2 emissions embodied in gross exports ', 'NLD', 'Netherlands', 'COL', 'DTOTAL', 'TOTAL', 1995, 0.075, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'NLD', 'Netherlands', 'COL', 'DTOTAL', 'TOTAL', 1996, 0.089, 'Mt CO2')
#   ('Domestic CO2 emissions embodied in gross exports ', 'NLD', 'Netherlands', 'COL', 'DTOTAL', 'TOTAL', 1997, 0.096, 'Mt CO2')
#   ...
#   ('Domestic CO2 emissions embodied in gross exports ', 'NZL', 'New Zealand', 'HRV', 'DTOTAL', 'TOTAL', 2002, 0.001, 'Mt CO2')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 df.to_sql(ingest_table,
#       2            con=engine,
#       3            schema=ingest_schema,
#       4            if_exists='append',
#       5            index=False,
#       6            method=osc.TrinoBatchInsert(batch_size = 5000, verbose = True))
#
# File /opt/app-root/lib64/python3.8/site-packages/pandas/core/generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# File /opt/app-root/lib64/python3.8/site-packages/pandas/io/sql.py:697, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     692 elif not isinstance(frame, DataFrame):
#     693     raise NotImplementedError(
#     694         "'frame' argument should be either a Series or a DataFrame"
#     695     )
# --> 697 return pandas_sql.to_sql(
#     698     frame,
#     699     name,
#     700     if_exists=if_exists,
#     701     index=index,
#     702     index_label=index_label,
#     703     schema=schema,
#     704     chunksize=chunksize,
#     705     dtype=dtype,
#     706     method=method,
#     707     engine=engine,
#     708     **engine_kwargs,
#     709 )
#
# File /opt/app-root/lib64/python3.8/site-packages/pandas/io/sql.py:1739, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1727 sql_engine = get_engine(engine)
#    1729 table = self.prep_table(
#    1730     frame=frame,
#    1731     name=name,
#    (...)
#    1736     dtype=dtype,
#    1737 )
# -> 1739 total_inserted = sql_engine.insert_records(
#    1740     table=table,
#    1741     con=self.connectable,
#    1742     frame=frame,
#    1743     name=name,
#    1744     index=index,
#    1745     schema=schema,
#    1746     chunksize=chunksize,
#    1747     method=method,
#    1748     **engine_kwargs,
#    1749 )
#    1751 self.check_case_sensitive(name=name, schema=schema)
#    1752 return total_inserted
#
# File /opt/app-root/lib64/python3.8/site-packages/pandas/io/sql.py:1322, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1319 from sqlalchemy import exc
#    1321 try:
# -> 1322     return table.insert(chunksize=chunksize, method=method)
#    1323 except exc.SQLAlchemyError as err:
#    1324     # GH34431
#    1325     # https://stackoverflow.com/a/67358288/6067848
#    1326     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1327     )|inf can not be used with MySQL"""
#
# File /opt/app-root/lib64/python3.8/site-packages/pandas/io/sql.py:950, in SQLTable.insert(self, chunksize, method)
#     947     break
#     949 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# --> 950 num_inserted = exec_insert(conn, keys, chunk_iter)
#     951 if num_inserted is None:
#     952     total_inserted = None
#
# File /opt/app-root/lib64/python3.8/site-packages/osc_ingest_trino/trino_utils.py:158, in TrinoBatchInsert.__call__(self, sqltbl, dbcxn, columns, data_iter)
#     156     # possible alternative: dispatch batches by total batch size in bytes
#     157     if len(batch) >= self.batch_size:
# --> 158         self._do_insert(dbcxn, fqname, batch)
#     159         batch = []
#     160 if len(batch) > 0:
#
# File /opt/app-root/lib64/python3.8/site-packages/osc_ingest_trino/trino_utils.py:183, in TrinoBatchInsert._do_insert(self, dbcxn, fqname, batch)
#     181 sql = text(f"insert into {fqname} values\n{valclause}")
#     182 # if self.verbose: print(f'{sql}')
# --> 183 qres = dbcxn.execute(sql)
#     184 x = qres.fetchall()
#     185 if self.verbose:
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/engine/base.py:1295, in Connection.execute(self, statement, *multiparams, **params)
#    1291     util.raise_(
#    1292         exc.ObjectNotExecutableError(statement), replace_context=err
#    1293     )
#    1294 else:
# -> 1295     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/sql/elements.py:325, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     321 def _execute_on_connection(
#     322     self, connection, multiparams, params, execution_options, _force=False
#     323 ):
#     324     if _force or self.supports_execution:
# --> 325         return connection._execute_clauseelement(
#     326             self, multiparams, params, execution_options
#     327         )
#     328     else:
#     329         raise exc.ObjectNotExecutableError(self)
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/engine/base.py:1487, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1475 compiled_cache = execution_options.get(
#    1476     "compiled_cache", self.engine._compiled_cache
#    1477 )
#    1479 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1480     dialect=dialect,
#    1481     compiled_cache=compiled_cache,
#    (...)
#    1485     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1486 )
# -> 1487 ret = self._execute_context(
#    1488     dialect,
#    1489     dialect.execution_ctx_cls._init_compiled,
#    1490     compiled_sql,
#    1491     distilled_params,
#    1492     execution_options,
#    1493     compiled_sql,
#    1494     distilled_params,
#    1495     elem,
#    1496     extracted_params,
#    1497     cache_hit=cache_hit,
#    1498 )
#    1499 if has_events:
#    1500     self.dispatch.after_execute(
#    1501         self,
#    1502         elem,
#    (...)
#    1506         ret,
#    1507     )
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/engine/base.py:1851, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1848             branched.close()
#    1850 except BaseException as e:
# -> 1851     self._handle_dbapi_exception(
#    1852         e, statement, parameters, cursor, context
#    1853     )
#    1855 return result
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/engine/base.py:2036, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2032         util.raise_(
#    2033             sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2034         )
#    2035     else:
# -> 2036         util.raise_(exc_info[1], with_traceback=exc_info[2])
#    2038 finally:
#    2039     del self._reentrant_error
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File /opt/app-root/lib64/python3.8/site-packages/sqlalchemy/engine/base.py:1808, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1806                 break
#    1807     if not evt_handled:
# -> 1808         self.dialect.do_execute(
#    1809             cursor, statement, parameters, context
#    1810         )
#    1812 if self._has_events or self.engine._has_events:
#    1813     self.dispatch.after_cursor_execute(
#    1814         self,
#    1815         cursor,
#    (...)
#    1819         context.executemany,
#    1820     )
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/sqlalchemy/dialect.py:338, in TrinoDialect.do_execute(self, cursor, statement, parameters, context)
#     333 cursor.execute(statement, parameters)
#     334 if context and context.should_autocommit:
#     335     # SQL statement only submitted to Trino server when cursor.fetch*() is called.
#     336     # For DDL (CREATE/ALTER/DROP) and DML (INSERT/UPDATE/DELETE) statement, call cursor.description
#     337     # to force submit statement immediately.
# --> 338     cursor.description
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/dbapi.py:266, in Cursor.description(self)
#     264 @property
#     265 def description(self):
# --> 266     if self._query.columns is None:
#     267         return None
#     269     # [ (name, type_code, display_size, internal_size, precision, scale, null_ok) ]
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/client.py:736, in TrinoQuery.columns(self)
#     732 if self.query_id:
#     733     while not self._columns and not self.finished and not self.cancelled:
#     734         # Columns don't return immediate after query is summited.
#     735         # Continue fetching data until columns are available and push fetched rows into buffer.
# --> 736         self._result._rows += self.fetch()
#     737 return self._columns
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/client.py:790, in TrinoQuery.fetch(self)
#     788 def fetch(self) -> List[List[Any]]:
#     789     """Continue fetching data for the current query_id"""
# --> 790     response = self._request.get(self._request.next_uri)
#     791     status = self._request.process(response)
#     792     self._update_state(status)
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/client.py:492, in TrinoRequest.get(self, url)
#     491 def get(self, url):
# --> 492     return self._get(
#     493         url,
#     494         headers=self.http_headers,
#     495         timeout=self._request_timeout,
#     496         proxies=PROXIES,
#     497     )
#
# File /opt/app-root/lib64/python3.8/site-packages/trino/client.py:841, in _retry_with.<locals>.wrapper.<locals>.decorated(*args, **kwargs)
#     839 for attempt in range(1, max_attempts + 1):
#     840     try:
# --> 841         result = func(*args, **kwargs)
#     842         if any(guard(result) for guard in conditions):
#     843             handle_retry.retry(func, args, kwargs, None, attempt)
#
# File /opt/app-root/lib64/python3.8/site-packages/requests/sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File /opt/app-root/lib64/python3.8/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File /opt/app-root/lib64/python3.8/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File /opt/app-root/lib64/python3.8/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File /opt/app-root/lib64/python3.8/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /opt/app-root/lib64/python3.8/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /opt/app-root/lib64/python3.8/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /usr/lib64/python3.8/http/client.py:1347, in HTTPConnection.getresponse(self)
#    1345 try:
#    1346     try:
# -> 1347         response.begin()
#    1348     except ConnectionError:
#    1349         self.close()
#
# File /usr/lib64/python3.8/http/client.py:307, in HTTPResponse.begin(self)
#     305 # read until we get a non-100 response
#     306 while True:
# --> 307     version, status, reason = self._read_status()
#     308     if status != CONTINUE:
#     309         break
#
# File /usr/lib64/python3.8/http/client.py:268, in HTTPResponse._read_status(self)
#     267 def _read_status(self):
# --> 268     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269     if len(line) > _MAXLINE:
#     270         raise LineTooLong("status line")
#
# File /usr/lib64/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File /usr/lib64/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib64/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
sql=f"""
select * from {ingest_catalog}.{ingest_schema}.{ingest_table} where partner_iso_code='CAN'"""
df = pd.read_sql(sql, engine)
df
#df.to_csv("exp.csv",index=False,encoding='utf-8')
